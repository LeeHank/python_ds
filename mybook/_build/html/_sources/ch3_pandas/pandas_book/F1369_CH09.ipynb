# %% [markdown]
# # 第9章：透過分組來進行聚合、過濾和轉換

# %%
df = pd.DataFrame({
    "col1": ["A", "A", "A", "A", "B", "B", "B", "B"],
    "col2": ["G", "Y", "G", "Y", "G", "Y", "G", "Y"],
    "col3": [1, 2, 3, 4, 5, 6, 7, 8],
    "col4": [4, 3, 2, 1, 3, 4, 9, 2]
})
df
# Out:
#   col1 col2  col3  col4
# 0    A    G     1     4
# 1    A    Y     2     3
# 2    A    G     3     2
# 3    A    Y     4     1
# 4    B    G     5     3
# 5    B    Y     6     4
# 6    B    G     7     9
# 7    B    Y     8     2

# %%
(
    df
        .groupby(["col1", "col2"], as_index = False)
        .agg({"col3": np.mean})
)
# Out:
#   col1 col2  col3
# 0    A    G   2.0
# 1    A    Y   3.0
# 2    B    G   6.0
# 3    B    Y   7.0

# %%
(
    df
        .groupby(["col1", "col2"], as_index = False)
        .apply(lambda x: x.assign(new = (x.col3-x.col3.mean())/x.col3.std()))
)
# Out:
#   col1 col2  col3  col4       new
# 0    A    G     1     4 -0.707107
# 1    A    Y     2     3 -0.707107
# 2    A    G     3     2  0.707107
# 3    A    Y     4     1  0.707107
# 4    B    G     5     3 -0.707107
# 5    B    Y     6     4 -0.707107
# 6    B    G     7     9  0.707107
# 7    B    Y     8     2  0.707107

# %%
df.groupby(["col1", "col2"]).apply(lambda x: x.assign(n = len(x)))
# Out:
#   col1 col2  col3  col4  n
# 0    A    G     1     4  2
# 1    A    Y     2     3  2
# 2    A    G     3     2  2
# 3    A    Y     4     1  2
# 4    B    G     5     3  2
# 5    B    Y     6     4  2
# 6    B    G     7     9  2
# 7    B    Y     8     2  2

# %%
df.groupby(["col1", "col2"]).apply(lambda x: x.sort_values("col4", ascending = False).loc[:, ["col3", "col4"]]).reset_index()
# Out:
#   col1 col2  level_2  col3  col4
# 0    A    G        0     1     4
# 1    A    G        2     3     2
# 2    A    Y        1     2     3
# 3    A    Y        3     4     1
# 4    B    G        6     7     9
# 5    B    G        4     5     3
# 6    B    Y        5     6     4
# 7    B    Y        7     8     2

# %% [markdown]
# ## 9.1 進行簡單的分組及聚合運算

# %%
import pandas as pd
import numpy as np
#pd.set_option('max_columns', 4, 'max_rows', 10)

flights = pd.read_csv('data/flights.csv')
flights.head()
# Out:
#    MONTH  DAY  WEEKDAY AIRLINE ORG_AIR DEST_AIR  SCHED_DEP  DEP_DELAY  \
# 0      1    1        4      WN     LAX      SLC       1625       58.0
# 1      1    1        4      UA     DEN      IAD        823        7.0
# 2      1    1        4      MQ     DFW      VPS       1305       36.0
# 3      1    1        4      AA     DFW      DCA       1555        7.0
# 4      1    1        4      WN     LAX      MCI       1720       48.0
#
#    AIR_TIME  DIST  SCHED_ARR  ARR_DELAY  DIVERTED  CANCELLED
# 0      94.0   590       1905       65.0         0          0
# 1     154.0  1452       1333      -13.0         0          0
# 2      85.0   641       1453       35.0         0          0
# 3     126.0  1192       1935       -7.0         0          0
# 4     166.0  1363       2225       39.0         0          0

# %%
np.mean(np.array([1, 2, np.nan]), )
# Out:
# nan

# %%
# ?np.percentile
# Out:
# Signature:
# np.percentile(
#     a,
#     q,
#     axis=None,
#     out=None,
#     overwrite_input=False,
#     interpolation='linear',
#     keepdims=False,
# )
# Docstring:
# Compute the q-th percentile of the data along the specified axis.
#
# Returns the q-th percentile(s) of the array elements.
#
# Parameters
# ----------
# a : array_like
#     Input array or object that can be converted to an array.
# q : array_like of float
#     Percentile or sequence of percentiles to compute, which must be between
#     0 and 100 inclusive.
# axis : {int, tuple of int, None}, optional
#     Axis or axes along which the percentiles are computed. The
#     default is to compute the percentile(s) along a flattened
#     version of the array.
#
#     .. versionchanged:: 1.9.0
#         A tuple of axes is supported
# out : ndarray, optional
#     Alternative output array in which to place the result. It must
#     have the same shape and buffer length as the expected output,
#     but the type (of the output) will be cast if necessary.
# overwrite_input : bool, optional
#     If True, then allow the input array `a` to be modified by intermediate
#     calculations, to save memory. In this case, the contents of the input
#     `a` after this function completes is undefined.
#
# interpolation : {'linear', 'lower', 'higher', 'midpoint', 'nearest'}
#     This optional parameter specifies the interpolation method to
#     use when the desired percentile lies between two data points
#     ``i < j``:
#
#     * 'linear': ``i + (j - i) * fraction``, where ``fraction``
#       is the fractional part of the index surrounded by ``i``
#       and ``j``.
#     * 'lower': ``i``.
#     * 'higher': ``j``.
#     * 'nearest': ``i`` or ``j``, whichever is nearest.
#     * 'midpoint': ``(i + j) / 2``.
#
#     .. versionadded:: 1.9.0
# keepdims : bool, optional
#     If this is set to True, the axes which are reduced are left in
#     the result as dimensions with size one. With this option, the
#     result will broadcast correctly against the original array `a`.
#
#     .. versionadded:: 1.9.0
#
# Returns
# -------
# percentile : scalar or ndarray
#     If `q` is a single percentile and `axis=None`, then the result
#     is a scalar. If multiple percentiles are given, first axis of
#     the result corresponds to the percentiles. The other axes are
#     the axes that remain after the reduction of `a`. If the input
#     contains integers or floats smaller than ``float64``, the output
#     data-type is ``float64``. Otherwise, the output data-type is the
#     same as that of the input. If `out` is specified, that array is
#     returned instead.
#
# See Also
# --------
# mean
# median : equivalent to ``percentile(..., 50)``
# nanpercentile
# quantile : equivalent to percentile, except with q in the range [0, 1].
#
# Notes
# -----
# Given a vector ``V`` of length ``N``, the q-th percentile of
# ``V`` is the value ``q/100`` of the way from the minimum to the
# maximum in a sorted copy of ``V``. The values and distances of
# the two nearest neighbors as well as the `interpolation` parameter
# will determine the percentile if the normalized ranking does not
# match the location of ``q`` exactly. This function is the same as
# the median if ``q=50``, the same as the minimum if ``q=0`` and the
# same as the maximum if ``q=100``.
#
# Examples
# --------
# >>> a = np.array([[10, 7, 4], [3, 2, 1]])
# >>> a
# array([[10,  7,  4],
#        [ 3,  2,  1]])
# >>> np.percentile(a, 50)
# 3.5
# >>> np.percentile(a, 50, axis=0)
# array([6.5, 4.5, 2.5])
# >>> np.percentile(a, 50, axis=1)
# array([7.,  2.])
# >>> np.percentile(a, 50, axis=1, keepdims=True)
# array([[7.],
#        [2.]])
#
# >>> m = np.percentile(a, 50, axis=0)
# >>> out = np.zeros_like(m)
# >>> np.percentile(a, 50, axis=0, out=out)
# array([6.5, 4.5, 2.5])
# >>> m
# array([6.5, 4.5, 2.5])
#
# >>> b = a.copy()
# >>> np.percentile(b, 50, axis=1, overwrite_input=True)
# array([7.,  2.])
# >>> assert not np.all(a == b)
#
# The different types of interpolation can be visualized graphically:
#
# .. plot::
#
#     import matplotlib.pyplot as plt
#
#     a = np.arange(4)
#     p = np.linspace(0, 100, 6001)
#     ax = plt.gca()
#     lines = [
#         ('linear', None),
#         ('higher', '--'),
#         ('lower', '--'),
#         ('nearest', '-.'),
#         ('midpoint', '-.'),
#     ]
#     for interpolation, style in lines:
#         ax.plot(
#             p, np.percentile(a, p, interpolation=interpolation),
#             label=interpolation, linestyle=style)
#     ax.set(
#         title='Interpolation methods for list: ' + str(a),
#         xlabel='Percentile',
#         ylabel='List item returned',
#         yticks=a)
#     ax.legend()
#     plt.show()
# File:      /Volumes/GoogleDrive/我的雲端硬碟/0. codepool_python/python_ds/python_ds_env/lib/python3.8/site-packages/numpy/lib/function_base.py
# Type:      function

# %%
flights.ARR_DELAY.quantile(0.5)
# Out:
# -4.0

# %%
flights.ARR_DELAY
# Out:
# 0        65.0
# 1       -13.0
# 2        35.0
# 3        -7.0
# 4        39.0
#          ...
# 58487   -19.0
# 58488     4.0
# 58489    -5.0
# 58490    34.0
# 58491    -1.0
# Name: ARR_DELAY, Length: 58492, dtype: float64

# %%
# ?pd.Series.mean
# Out:
# Signature:
# pd.Series.mean(
#     self,
#     axis: 'int | None | lib.NoDefault' = <no_default>,
#     skipna=True,
#     level=None,
#     numeric_only=None,
#     **kwargs,
# )
# Docstring:
# Return the mean of the values over the requested axis.
#
# Parameters
# ----------
# axis : {index (0)}
#     Axis for the function to be applied on.
# skipna : bool, default True
#     Exclude NA/null values when computing the result.
# level : int or level name, default None
#     If the axis is a MultiIndex (hierarchical), count along a
#     particular level, collapsing into a scalar.
# numeric_only : bool, default None
#     Include only float, int, boolean columns. If None, will attempt to use
#     everything, then use only numeric data. Not implemented for Series.
# **kwargs
#     Additional keyword arguments to be passed to the function.
#
# Returns
# -------
# scalar or Series (if level specified)
# File:      /Volumes/GoogleDrive/我的雲端硬碟/0. codepool_python/python_ds/python_ds_env/lib/python3.8/site-packages/pandas/core/generic.py
# Type:      function

# %%
(
    flights
        .groupby("AIRLINE")
        .loc[:, "ARR_DELAY"]
        .mean()
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <module>
#       1 (
# ----> 2     flights
#       3         .groupby("AIRLINE")
#       4         .loc[:, "ARR_DELAY"]
#       5         .mean()
#       6 )
#
# File /Volumes/GoogleDrive/我的雲端硬碟/0. codepool_python/python_ds/python_ds_env/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'loc'

# %%
(
    flights
        .groupby("AIRLINE")
        .agg(sd_arr_delay = pd.NamedAgg("ARR_DELAY", np.std))
        .reset_index()
)
# Out:
#    AIRLINE  sd_arr_delay
# 0       AA     43.323160
# 1       AS     31.168354
# 2       B6     40.221718
# 3       DL     32.299471
# 4       EV     36.682336
# 5       F9     53.030912
# 6       HA     37.528283
# 7       MQ     36.324657
# 8       NK     48.727259
# 9       OO     35.331344
# 10      UA     46.405935
# 11      US     27.030227
# 12      VX     33.747675
# 13      WN     32.610666

# %%
(
    flights
        .groupby("AIRLINE", as_index=False)
        .agg(sd_arr_delay = pd.NamedAgg("ARR_DELAY", "std"),
             mean_arr_delay = pd.NamedAgg("ARR_DELAY", lambda x: x.mean(skipna=True)),
            pr50_arr_delay = pd.NamedAgg("ARR_DELAY", lambda x: np.quantile(x, q = 0.5)))
        .assign(plus_one = lambda x: x.mean_arr_delay + 1)
        .assign(z_score = lambda x: (x.plus_one - x.plus_one.mean())/x.plus_one.std())
)
# Out:
#    AIRLINE  sd_arr_delay  mean_arr_delay  pr50_arr_delay   plus_one   z_score
# 0       AA     43.323160        5.542661             NaN   6.542661 -0.228262
# 1       AS     31.168354       -0.833333            -6.0   0.166667 -1.512509
# 2       B6     40.221718        8.692593             NaN   9.692593  0.406194
# 3       DL     32.299471        0.339691             NaN   1.339691 -1.276240
# 4       EV     36.682336        7.034580             NaN   8.034580  0.072239
# 5       F9     53.030912       13.630651             NaN  14.630651  1.400813
# 6       HA     37.528283        4.972973             NaN   5.972973 -0.343008
# 7       MQ     36.324657        6.860591             NaN   7.860591  0.037194
# 8       NK     48.727259       18.436070             NaN  19.436070  2.368717
# 9       OO     35.331344        7.593463             NaN   8.593463  0.184808
# 10      UA     46.405935        7.765755             NaN   8.765755  0.219511
# 11      US     27.030227        1.681105             NaN   2.681105 -1.006053
# 12      VX     33.747675        5.348884             NaN   6.348884 -0.267293
# 13      WN     32.610666        6.397353             NaN   7.397353 -0.056111

# %%
(
    flights
        .groupby("AIRLINE", as_index=False)
        .agg(sd_arr_delay = pd.NamedAgg("ARR_DELAY", "std"),
             mean_arr_delay = pd.NamedAgg("ARR_DELAY", lambda x: x.mean(skipna=True)),
            pr50_arr_delay = pd.NamedAgg("ARR_DELAY", lambda x: x.quantile(0.5)))
        .assign(plus_one = lambda x: x.mean_arr_delay + 1)
        .assign(z_score = lambda x: (x.plus_one - x.plus_one.mean())/x.plus_one.std())
)
# Out:
#    AIRLINE  sd_arr_delay  mean_arr_delay  pr50_arr_delay   plus_one   z_score
# 0       AA     43.323160        5.542661            -5.0   6.542661 -0.228262
# 1       AS     31.168354       -0.833333            -6.0   0.166667 -1.512509
# 2       B6     40.221718        8.692593            -2.0   9.692593  0.406194
# 3       DL     32.299471        0.339691            -7.0   1.339691 -1.276240
# 4       EV     36.682336        7.034580            -3.0   8.034580  0.072239
# 5       F9     53.030912       13.630651            -1.0  14.630651  1.400813
# 6       HA     37.528283        4.972973             0.0   5.972973 -0.343008
# 7       MQ     36.324657        6.860591            -4.0   7.860591  0.037194
# 8       NK     48.727259       18.436070             2.0  19.436070  2.368717
# 9       OO     35.331344        7.593463            -3.0   8.593463  0.184808
# 10      UA     46.405935        7.765755            -4.0   8.765755  0.219511
# 11      US     27.030227        1.681105            -4.0   2.681105 -1.006053
# 12      VX     33.747675        5.348884            -3.0   6.348884 -0.267293
# 13      WN     32.610666        6.397353            -3.0   7.397353 -0.056111

# %%
(flights
     .groupby('AIRLINE')
     .agg({'ARR_DELAY':'mean'})
)
# Out:
#          ARR_DELAY
# AIRLINE
# AA        5.542661
# AS       -0.833333
# B6        8.692593
# DL        0.339691
# EV        7.034580
# ...            ...
# OO        7.593463
# UA        7.765755
# US        1.681105
# VX        5.348884
# WN        6.397353
#
# [14 rows x 1 columns]

# %%
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .agg('mean')
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .agg(np.mean)
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
(flights
     .groupby('AIRLINE')
     ['ARR_DELAY']
     .mean()
)
# Out:
# AIRLINE
# AA    5.542661
# AS   -0.833333
# B6    8.692593
# DL    0.339691
# EV    7.034580
#         ...
# OO    7.593463
# UA    7.765755
# US    1.681105
# VX    5.348884
# WN    6.397353
# Name: ARR_DELAY, Length: 14, dtype: float64

# %%
# (flights
#    .groupby('AIRLINE')
#    ['ARR_DELAY']
#    .agg(np.sqrt)
# )

# %% [markdown]
# ## 9.2 對多個欄位執行分組及聚合運算

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    ['CANCELLED'] 
    .agg('sum')
)
# Out:
# AIRLINE  WEEKDAY
# AA       1          41
#          2           9
#          3          16
#          4          20
#          5          18
#                     ..
# WN       3          18
#          4          10
#          5           7
#          6          10
#          7           7
# Name: CANCELLED, Length: 98, dtype: int64

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY']) 
    ['CANCELLED', 'DIVERTED']
    .agg(['sum', 'mean'])
)
# Out:
# <ipython-input-8-fb02002e28ce>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (flights
#                 CANCELLED           DIVERTED
#                       sum      mean      sum      mean
# AIRLINE WEEKDAY
# AA      1              41  0.032106        6  0.004699
#         2               9  0.007341        2  0.001631
#         3              16  0.011949        2  0.001494
#         4              20  0.015004        5  0.003751
#         5              18  0.014151        1  0.000786
# ...                   ...       ...      ...       ...
# WN      3              18  0.014118        2  0.001569
#         4              10  0.007911        4  0.003165
#         5               7  0.005828        0  0.000000
#         6              10  0.010132        3  0.003040
#         7               7  0.006066        3  0.002600
#
# [98 rows x 4 columns]

# %%
(flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
# Out:
#                  CANCELLED            ...    AIR_TIME
#                        sum      mean  ...        mean         var
# ORG_AIR DEST_AIR                      ...
# ATL     ABE              0  0.000000  ...   96.387097   45.778495
#         ABQ              0  0.000000  ...  170.500000   87.866667
#         ABY              0  0.000000  ...   28.578947    6.590643
#         ACY              0  0.000000  ...   91.333333   11.466667
#         AEX              0  0.000000  ...   78.725000   47.332692
# ...                    ...       ...  ...         ...         ...
# SFO     SNA              4  0.032787  ...   64.059322   11.338331
#         STL              0  0.000000  ...  198.900000  101.042105
#         SUN              0  0.000000  ...   78.000000   25.777778
#         TUS              0  0.000000  ...  100.200000   35.221053
#         XNA              0  0.000000  ...  173.500000    0.500000
#
# [1130 rows x 5 columns]

# %%
(flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg(sum_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='sum'),
         mean_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='mean'),
         size_cancelled=pd.NamedAgg(column='CANCELLED', aggfunc='size'),
         mean_air_time=pd.NamedAgg(column='AIR_TIME', aggfunc='mean'),
         var_air_time=pd.NamedAgg(column='AIR_TIME', aggfunc='var'))
)
# Out:
#                   sum_cancelled  mean_cancelled  ...  mean_air_time  \
# ORG_AIR DEST_AIR                                 ...
# ATL     ABE                   0        0.000000  ...      96.387097
#         ABQ                   0        0.000000  ...     170.500000
#         ABY                   0        0.000000  ...      28.578947
#         ACY                   0        0.000000  ...      91.333333
#         AEX                   0        0.000000  ...      78.725000
# ...                         ...             ...  ...            ...
# SFO     SNA                   4        0.032787  ...      64.059322
#         STL                   0        0.000000  ...     198.900000
#         SUN                   0        0.000000  ...      78.000000
#         TUS                   0        0.000000  ...     100.200000
#         XNA                   0        0.000000  ...     173.500000
#
#                   var_air_time
# ORG_AIR DEST_AIR
# ATL     ABE          45.778495
#         ABQ          87.866667
#         ABY           6.590643
#         ACY          11.466667
#         AEX          47.332692
# ...                        ...
# SFO     SNA          11.338331
#         STL         101.042105
#         SUN          25.777778
#         TUS          35.221053
#         XNA           0.500000
#
# [1130 rows x 5 columns]

# %%
res = (flights.groupby(['ORG_AIR', 'DEST_AIR'])
              .agg({'CANCELLED':['sum', 'mean', 'size'],
                    'AIR_TIME':['mean', 'var']})
)
res.columns
# Out:
# MultiIndex([('CANCELLED',  'sum'),
#             ('CANCELLED', 'mean'),
#             ('CANCELLED', 'size'),
#             ( 'AIR_TIME', 'mean'),
#             ( 'AIR_TIME',  'var')],
#            )

# %%
res_flat_column = res.columns.to_flat_index()
res_flat_column
# Out:
# Index([ ('CANCELLED', 'sum'), ('CANCELLED', 'mean'), ('CANCELLED', 'size'),
#         ('AIR_TIME', 'mean'),   ('AIR_TIME', 'var')],
#       dtype='object')

# %%
res.columns = ['_'.join(x) for x in res_flat_column]
res
# Out:
#                   CANCELLED_sum  CANCELLED_mean  ...  AIR_TIME_mean  \
# ORG_AIR DEST_AIR                                 ...
# ATL     ABE                   0        0.000000  ...      96.387097
#         ABQ                   0        0.000000  ...     170.500000
#         ABY                   0        0.000000  ...      28.578947
#         ACY                   0        0.000000  ...      91.333333
#         AEX                   0        0.000000  ...      78.725000
# ...                         ...             ...  ...            ...
# SFO     SNA                   4        0.032787  ...      64.059322
#         STL                   0        0.000000  ...     198.900000
#         SUN                   0        0.000000  ...      78.000000
#         TUS                   0        0.000000  ...     100.200000
#         XNA                   0        0.000000  ...     173.500000
#
#                   AIR_TIME_var
# ORG_AIR DEST_AIR
# ATL     ABE          45.778495
#         ABQ          87.866667
#         ABY           6.590643
#         ACY          11.466667
#         AEX          47.332692
# ...                        ...
# SFO     SNA          11.338331
#         STL         101.042105
#         SUN          25.777778
#         TUS          35.221053
#         XNA           0.500000
#
# [1130 rows x 5 columns]

# %%
def flatten_cols(df):
    df.columns = ['_'.join(x) for x in df.columns.to_flat_index()]
    return df

res = (flights
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
    .pipe(flatten_cols)
)

res
# Out:
#                   CANCELLED_sum  CANCELLED_mean  ...  AIR_TIME_mean  \
# ORG_AIR DEST_AIR                                 ...
# ATL     ABE                   0        0.000000  ...      96.387097
#         ABQ                   0        0.000000  ...     170.500000
#         ABY                   0        0.000000  ...      28.578947
#         ACY                   0        0.000000  ...      91.333333
#         AEX                   0        0.000000  ...      78.725000
# ...                         ...             ...  ...            ...
# SFO     SNA                   4        0.032787  ...      64.059322
#         STL                   0        0.000000  ...     198.900000
#         SUN                   0        0.000000  ...      78.000000
#         TUS                   0        0.000000  ...     100.200000
#         XNA                   0        0.000000  ...     173.500000
#
#                   AIR_TIME_var
# ORG_AIR DEST_AIR
# ATL     ABE          45.778495
#         ABQ          87.866667
#         ABY           6.590643
#         ACY          11.466667
#         AEX          47.332692
# ...                        ...
# SFO     SNA          11.338331
#         STL         101.042105
#         SUN          25.777778
#         TUS          35.221053
#         XNA           0.500000
#
# [1130 rows x 5 columns]

# %%
res = (flights
    .assign(ORG_AIR=flights.ORG_AIR.astype('category'))
    .groupby(['ORG_AIR', 'DEST_AIR'])
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
res
# Out:
#                  CANCELLED       ...    AIR_TIME
#                        sum mean  ...        mean        var
# ORG_AIR DEST_AIR                 ...
# ATL     ABE            0.0  0.0  ...   96.387097  45.778495
#         ABI            NaN  NaN  ...         NaN        NaN
#         ABQ            0.0  0.0  ...  170.500000  87.866667
#         ABR            NaN  NaN  ...         NaN        NaN
#         ABY            0.0  0.0  ...   28.578947   6.590643
# ...                    ...  ...  ...         ...        ...
# SFO     TYS            NaN  NaN  ...         NaN        NaN
#         VLD            NaN  NaN  ...         NaN        NaN
#         VPS            NaN  NaN  ...         NaN        NaN
#         XNA            0.0  0.0  ...  173.500000   0.500000
#         YUM            NaN  NaN  ...         NaN        NaN
#
# [2710 rows x 5 columns]

# %%
res = (flights
    .assign(ORG_AIR=flights.ORG_AIR.astype('category'))
    .groupby(['ORG_AIR', 'DEST_AIR'], observed=True)
    .agg({'CANCELLED':['sum', 'mean', 'size'],
          'AIR_TIME':['mean', 'var']})
)
res
# Out:
#                  CANCELLED            ...    AIR_TIME
#                        sum      mean  ...        mean         var
# ORG_AIR DEST_AIR                      ...
# LAX     ABQ              1  0.018182  ...   89.259259   29.403215
#         ANC              0  0.000000  ...  307.428571   78.952381
#         ASE              1  0.038462  ...  102.920000  102.243333
#         ATL              0  0.000000  ...  224.201149  127.155837
#         AUS              0  0.000000  ...  150.537500   57.897310
# ...                    ...       ...  ...         ...         ...
# MSP     TTN              1  0.125000  ...  124.428571   57.952381
#         TUL              0  0.000000  ...   91.611111   63.075163
#         TUS              0  0.000000  ...  176.000000   32.000000
#         TVC              0  0.000000  ...   56.600000   10.300000
#         XNA              0  0.000000  ...   90.642857  115.939560
#
# [1130 rows x 5 columns]

# %% [markdown]
# ## 9.3 分組後刪除MultiIndex

# %%
flights = pd.read_csv('data/flights.csv')
airline_info = (flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    .agg({'DIST':['sum', 'mean'],
          'ARR_DELAY':['min', 'max']}) 
    .astype(int)
)
airline_info
# Out:
#                     DIST       ARR_DELAY
#                      sum  mean       min  max
# AIRLINE WEEKDAY
# AA      1        1455386  1139       -60  551
#         2        1358256  1107       -52  725
#         3        1496665  1117       -45  473
#         4        1452394  1089       -46  349
#         5        1427749  1122       -41  732
# ...                  ...   ...       ...  ...
# WN      3         997213   782       -38  262
#         4        1024854   810       -52  284
#         5         981036   816       -44  244
#         6         823946   834       -41  290
#         7         945679   819       -45  261
#
# [98 rows x 4 columns]

# %%
airline_info.columns.get_level_values(0)
# Out:
# Index(['DIST', 'DIST', 'ARR_DELAY', 'ARR_DELAY'], dtype='object')

# %%
airline_info.columns.get_level_values(1)
# Out:
# Index(['sum', 'mean', 'min', 'max'], dtype='object')

# %%
airline_info.columns.to_flat_index()
# Out:
# Index([('DIST', 'sum'), ('DIST', 'mean'), ('ARR_DELAY', 'min'),
#        ('ARR_DELAY', 'max')],
#       dtype='object')

# %%
airline_info.columns = ['_'.join(x) for x in
    airline_info.columns.to_flat_index()]

airline_info
# Out:
#                  DIST_sum  DIST_mean  ARR_DELAY_min  ARR_DELAY_max
# AIRLINE WEEKDAY
# AA      1         1455386       1139            -60            551
#         2         1358256       1107            -52            725
#         3         1496665       1117            -45            473
#         4         1452394       1089            -46            349
#         5         1427749       1122            -41            732
# ...                   ...        ...            ...            ...
# WN      3          997213        782            -38            262
#         4         1024854        810            -52            284
#         5          981036        816            -44            244
#         6          823946        834            -41            290
#         7          945679        819            -45            261
#
# [98 rows x 4 columns]

# %%
airline_info.reset_index()
# Out:
#    AIRLINE  WEEKDAY  ...  ARR_DELAY_min  ARR_DELAY_max
# 0       AA        1  ...            -60            551
# 1       AA        2  ...            -52            725
# 2       AA        3  ...            -45            473
# 3       AA        4  ...            -46            349
# 4       AA        5  ...            -41            732
# ..     ...      ...  ...            ...            ...
# 93      WN        3  ...            -38            262
# 94      WN        4  ...            -52            284
# 95      WN        5  ...            -44            244
# 96      WN        6  ...            -41            290
# 97      WN        7  ...            -45            261
#
# [98 rows x 6 columns]

# %%
(flights
    .groupby(['AIRLINE', 'WEEKDAY'])
    .agg(dist_sum=pd.NamedAgg(column='DIST', aggfunc='sum'),
         dist_mean=pd.NamedAgg(column='DIST', aggfunc='mean'),
         arr_delay_min=pd.NamedAgg(column='ARR_DELAY', aggfunc='min'),
         arr_delay_max=pd.NamedAgg(column='ARR_DELAY', aggfunc='max'))
    .astype(int)
    .reset_index()
)
# Out:
#    AIRLINE  WEEKDAY  ...  arr_delay_min  arr_delay_max
# 0       AA        1  ...            -60            551
# 1       AA        2  ...            -52            725
# 2       AA        3  ...            -45            473
# 3       AA        4  ...            -46            349
# 4       AA        5  ...            -41            732
# ..     ...      ...  ...            ...            ...
# 93      WN        3  ...            -38            262
# 94      WN        4  ...            -52            284
# 95      WN        5  ...            -44            244
# 96      WN        6  ...            -41            290
# 97      WN        7  ...            -45            261
#
# [98 rows x 6 columns]

# %%
(flights
    .groupby(['AIRLINE'], as_index=False)
    ['DIST']
    .agg('mean')
    .round(0)
)
# Out:
#    AIRLINE    DIST
# 0       AA  1114.0
# 1       AS  1066.0
# 2       B6  1772.0
# 3       DL   866.0
# 4       EV   460.0
# ..     ...     ...
# 9       OO   511.0
# 10      UA  1231.0
# 11      US  1181.0
# 12      VX  1240.0
# 13      WN   810.0
#
# [14 rows x 2 columns]

# %% [markdown]
# ## 9.4 使用自訂的聚合函式來分組

# %%
college = pd.read_csv('data/college.csv')
(college
    .groupby('STABBR')
    ['UGDS']
    .agg(['mean', 'std'])
    .round(0)
)
# Out:
#           mean      std
# STABBR
# AK      2493.0   4052.0
# AL      2790.0   4658.0
# AR      1644.0   3143.0
# AS      1276.0      NaN
# AZ      4130.0  14894.0
# ...        ...      ...
# VT      1513.0   2194.0
# WA      2271.0   4124.0
# WI      2655.0   4615.0
# WV      1758.0   5957.0
# WY      2244.0   2745.0
#
# [59 rows x 2 columns]

# %%
def max_deviation(s):
    std_score = (s - s.mean()) / s.std()
    return std_score.abs().max()

# %%
(college
    .groupby('STABBR')
    ['UGDS']
    .agg(max_deviation)
    .round(1)
)
# Out:
# STABBR
# AK    2.6
# AL    5.8
# AR    6.3
# AS    NaN
# AZ    9.9
#      ...
# VT    3.8
# WA    6.6
# WI    5.8
# WV    7.2
# WY    2.8
# Name: UGDS, Length: 59, dtype: float64

# %%
(college
    .groupby('STABBR')
    ['UGDS', 'SATVRMID', 'SATMTMID']
    .agg(max_deviation)
    .round(1)
)
# Out:
# <ipython-input-28-fb803eab90b9>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#         UGDS  SATVRMID  SATMTMID
# STABBR
# AK       2.6       NaN       NaN
# AL       5.8       1.6       1.8
# AR       6.3       2.2       2.3
# AS       NaN       NaN       NaN
# AZ       9.9       1.9       1.4
# ...      ...       ...       ...
# VT       3.8       1.9       1.9
# WA       6.6       2.2       2.0
# WI       5.8       2.4       2.2
# WV       7.2       1.7       2.1
# WY       2.8       NaN       NaN
#
# [59 rows x 3 columns]

# %%
(college
    .groupby(['STABBR']) 
    ['UGDS'] 
    .agg([max_deviation, 'mean', 'std'])
    .round(1)
)
# Out:
#         max_deviation    mean      std
# STABBR
# AK                2.6  2493.2   4051.7
# AL                5.8  2789.9   4657.9
# AR                6.3  1644.1   3142.8
# AS                NaN  1276.0      NaN
# AZ                9.9  4130.5  14893.6
# ...               ...     ...      ...
# VT                3.8  1512.6   2193.6
# WA                6.6  2271.2   4123.7
# WI                5.8  2655.5   4615.5
# WV                7.2  1758.1   5957.2
# WY                2.8  2244.4   2744.7
#
# [59 rows x 3 columns]

# %%
max_deviation.__name__
# Out:
# 'max_deviation'

# %%
max_deviation.__name__ = 'Max Deviation'
(college
    .groupby(['STABBR', 'RELAFFIL']) 
    ['UGDS', 'SATVRMID', 'SATMTMID'] 
    .agg([max_deviation, 'mean', 'std'])
    .round(1)
)
# Out:
# <ipython-input-31-42a7cc7ba9cb>:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   (college
#                          UGDS          ... SATMTMID
#                 Max Deviation    mean  ...     mean   std
# STABBR RELAFFIL                        ...
# AK     0                  2.1  3508.9  ...      NaN   NaN
#        1                  1.1   123.3  ...    503.0   NaN
# AL     0                  5.2  3248.8  ...    515.8  56.7
#        1                  2.4   979.7  ...    485.6  61.4
# AR     0                  5.8  1793.7  ...    503.6  39.0
# ...                       ...     ...  ...      ...   ...
# WI     0                  5.3  2879.1  ...    591.2  85.7
#        1                  3.4  1716.2  ...    526.6  42.5
# WV     0                  6.9  1873.9  ...    480.0  27.7
#        1                  1.3   716.4  ...    484.8  17.7
# WY     0                  2.8  2244.4  ...    540.0   NaN
#
# [112 rows x 9 columns]

# %% [markdown]
# ## 9.5 可接收多個參數的自訂聚合函式

# %%
def pct_between_1_3k(s):
    return (s.between(1_000, 3_000)
             .mean()* 100)

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between_1_3k)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           14.3
#         1            0.0
# AL      0           23.6
#         1           33.3
# AR      0           27.9
#                     ...
# WI      0           13.8
#         1           36.0
# WV      0           24.6
#         1           37.5
# WY      0           54.5
# Name: UGDS, Length: 112, dtype: float64

# %%
def pct_between(s, low, high):
    return s.between(low, high).mean() * 100

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between, 1_000, 10_000)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           42.9
#         1            0.0
# AL      0           45.8
#         1           37.5
# AR      0           39.7
#                     ...
# WI      0           31.0
#         1           44.0
# WV      0           29.2
#         1           37.5
# WY      0           72.7
# Name: UGDS, Length: 112, dtype: float64

# %%
(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg(pct_between, low=1_000, high=10_000)
    .round(1)
)
# Out:
# STABBR  RELAFFIL
# AK      0           42.9
#         1            0.0
# AL      0           45.8
#         1           37.5
# AR      0           39.7
#                     ...
# WI      0           31.0
#         1           44.0
# WV      0           29.2
#         1           37.5
# WY      0           72.7
# Name: UGDS, Length: 112, dtype: float64

# %%
def between_n_m(n, m):
    def wrapper(ser):
        return pct_between(ser, n, m)
    wrapper.__name__ = f'between_{n}_{m}'
    return wrapper

(college
    .groupby(['STABBR', 'RELAFFIL'])
    ['UGDS'] 
    .agg([between_n_m(1_000, 10_000), 'max', 'mean'])
    .round(1)
)
# Out:
#                  between_1000_10000      max    mean
# STABBR RELAFFIL
# AK     0                       42.9  12865.0  3508.9
#        1                        0.0    275.0   123.3
# AL     0                       45.8  29851.0  3248.8
#        1                       37.5   3033.0   979.7
# AR     0                       39.7  21405.0  1793.7
# ...                             ...      ...     ...
# WI     0                       31.0  29302.0  2879.1
#        1                       44.0   8212.0  1716.2
# WV     0                       29.2  44924.0  1873.9
#        1                       37.5   1375.0   716.4
# WY     0                       72.7   9910.0  2244.4
#
# [112 rows x 3 columns]

# %% [markdown]
# ## 9.6 深入了解groupby物件

# %%
college = pd.read_csv('data/college.csv')
grouped = college.groupby(['STABBR', 'RELAFFIL'])
type(grouped)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
college.columns
# Out:
# Index(['INSTNM', 'CITY', 'STABBR', 'HBCU', 'MENONLY', 'WOMENONLY', 'RELAFFIL',
#        'SATVRMID', 'SATMTMID', 'DISTANCEONLY', 'UGDS', 'UGDS_WHITE',
#        'UGDS_BLACK', 'UGDS_HISP', 'UGDS_ASIAN', 'UGDS_AIAN', 'UGDS_NHPI',
#        'UGDS_2MOR', 'UGDS_NRA', 'UGDS_UNKN', 'PPTUG_EF', 'CURROPER', 'PCTPELL',
#        'PCTFLOAN', 'UG25ABV', 'MD_EARN_WNE_P10', 'GRAD_DEBT_MDN_SUPP'],
#       dtype='object')

# %%
print([attr for attr in dir(grouped) if not
    attr.startswith('_')])
# Out:
# ['CITY', 'CURROPER', 'DISTANCEONLY', 'GRAD_DEBT_MDN_SUPP', 'HBCU', 'INSTNM', 'MD_EARN_WNE_P10', 'MENONLY', 'PCTFLOAN', 'PCTPELL', 'PPTUG_EF', 'RELAFFIL', 'SATMTMID', 'SATVRMID', 'STABBR', 'UG25ABV', 'UGDS', 'UGDS_2MOR', 'UGDS_AIAN', 'UGDS_ASIAN', 'UGDS_BLACK', 'UGDS_HISP', 'UGDS_NHPI', 'UGDS_NRA', 'UGDS_UNKN', 'UGDS_WHITE', 'WOMENONLY', 'agg', 'aggregate', 'all', 'any', 'apply', 'backfill', 'bfill', 'boxplot', 'corr', 'corrwith', 'count', 'cov', 'cumcount', 'cummax', 'cummin', 'cumprod', 'cumsum', 'describe', 'diff', 'dtypes', 'expanding', 'ffill', 'fillna', 'filter', 'first', 'get_group', 'groups', 'head', 'hist', 'idxmax', 'idxmin', 'indices', 'last', 'mad', 'max', 'mean', 'median', 'min', 'ndim', 'ngroup', 'ngroups', 'nth', 'nunique', 'ohlc', 'pad', 'pct_change', 'pipe', 'plot', 'prod', 'quantile', 'rank', 'resample', 'rolling', 'sem', 'shift', 'size', 'skew', 'std', 'sum', 'tail', 'take', 'transform', 'tshift', 'var']

# %%
grouped.ngroups
# Out:
# 112

# %%
groups = list(grouped.groups)
groups[:6]
# Out:
# [('AK', 0), ('AK', 1), ('AL', 0), ('AL', 1), ('AR', 0), ('AR', 1)]

# %%
grouped.get_group(('FL', 1))
# Out:
#                                          INSTNM             CITY STABBR  HBCU  \
# 712              The Baptist College of Florida       Graceville     FL   0.0
# 713                            Barry University            Miami     FL   0.0
# 714       Gooding Institute of Nurse Anesthesia      Panama City     FL   0.0
# 715                  Bethune-Cookman University    Daytona Beach     FL   1.0
# 724                  Johnson University Florida        Kissimmee     FL   0.0
# ...                                         ...              ...    ...   ...
# 7486    Strayer University-Coral Springs Campus    Coral Springs     FL   NaN
# 7487  Strayer University-Fort Lauderdale Campus  Fort Lauderdale     FL   NaN
# 7488          Strayer University-Miramar Campus          Miramar     FL   NaN
# 7489                   Strayer University-Doral            Miami     FL   NaN
# 7490                Strayer University-Brickell            Miami     FL   NaN
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 712       0.0        0.0         1     545.0     465.0           0.0  ...
# 713       0.0        0.0         1     470.0     462.0           0.0  ...
# 714       0.0        0.0         1       NaN       NaN           0.0  ...
# 715       0.0        0.0         1     405.0     395.0           0.0  ...
# 724       0.0        0.0         1     480.0     470.0           0.0  ...
# ...       ...        ...       ...       ...       ...           ...  ...
# 7486      NaN        NaN         1       NaN       NaN           NaN  ...
# 7487      NaN        NaN         1       NaN       NaN           NaN  ...
# 7488      NaN        NaN         1       NaN       NaN           NaN  ...
# 7489      NaN        NaN         1       NaN       NaN           NaN  ...
# 7490      NaN        NaN         1       NaN       NaN           NaN  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 712      0.0308    0.0000     0.0507    0.2291         1   0.5878    0.5602
# 713      0.0164    0.0741     0.0841    0.1518         1   0.5045    0.6733
# 714         NaN       NaN        NaN       NaN         0      NaN       NaN
# 715      0.0198    0.0205     0.0190    0.0523         1   0.7758    0.8867
# 724      0.0045    0.0045     0.0136    0.1636         1   0.6689    0.7384
# ...         ...       ...        ...       ...       ...      ...       ...
# 7486        NaN       NaN        NaN       NaN         0      NaN       NaN
# 7487        NaN       NaN        NaN       NaN         1      NaN       NaN
# 7488        NaN       NaN        NaN       NaN         1      NaN       NaN
# 7489        NaN       NaN        NaN       NaN         1      NaN       NaN
# 7490        NaN       NaN        NaN       NaN         1      NaN       NaN
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 712    0.3531            30800               20052
# 713    0.4361            44100               28250
# 714       NaN              NaN   PrivacySuppressed
# 715    0.0647            29400               36250
# 724    0.2185            26300               20199
# ...       ...              ...                 ...
# 7486      NaN            49200             36173.5
# 7487      NaN            49200             36173.5
# 7488      NaN            49200             36173.5
# 7489      NaN            49200             36173.5
# 7490      NaN            49200             36173.5
#
# [89 rows x 27 columns]

# %%
from IPython.display import display
for name, group in grouped:
    print(name)
    display(group.head(3))
# Out:
# ('AK', 0)
#                             INSTNM       CITY STABBR  HBCU  MENONLY  \
# 60  University of Alaska Anchorage  Anchorage     AK   0.0      0.0
# 62  University of Alaska Fairbanks  Fairbanks     AK   0.0      0.0
# 63  University of Alaska Southeast     Juneau     AK   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 60        0.0         0       NaN       NaN           0.0  ...     0.0980
# 62        0.0         0       NaN       NaN           0.0  ...     0.0401
# 63        0.0         0       NaN       NaN           0.0  ...     0.0686
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 60    0.0181     0.0457    0.4539         1   0.2385    0.2647   0.4386
# 62    0.0110     0.3060    0.3887         1   0.2263    0.2550   0.4519
# 63    0.0049     0.2241    0.5112         1   0.1769    0.1996   0.5550
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 60            42500             19449.5
# 62            36200               19355
# 63            37400               16875
#
# [3 rows x 27 columns]
# ('AK', 1)
#                          INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 61         Alaska Bible College     Palmer     AK   0.0      0.0        0.0
# 64    Alaska Pacific University  Anchorage     AK   0.0      0.0        0.0
# 5417   Alaska Christian College   Soldotna     AK   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 61           1       NaN       NaN           0.0  ...     0.0370       0.0
# 64           1     555.0     503.0           0.0  ...     0.0945       0.0
# 5417         1       NaN       NaN           0.0  ...     0.0147       0.0
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 61       0.0000    0.1481         1   0.3571    0.2857   0.4286
# 64       0.0873    0.3745         1   0.3152    0.5297   0.4910
# 5417     0.1324    0.0735         1   0.8868    0.6792   0.2264
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 61                NaN   PrivacySuppressed
# 64              47000               23250
# 5417              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('AL', 0)
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 0             Alabama A & M University      Normal     AL   1.0      0.0
# 1  University of Alabama at Birmingham  Birmingham     AL   0.0      0.0
# 3  University of Alabama in Huntsville  Huntsville     AL   0.0      0.0
#
#    WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 0        0.0         0     424.0     420.0           0.0  ...     0.0000
# 1        0.0         0     570.0     565.0           0.0  ...     0.0368
# 3        0.0         0     595.0     590.0           0.0  ...     0.0172
#
#    UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 0    0.0059     0.0138    0.0656         1   0.7356    0.8284   0.1049
# 1    0.0179     0.0100    0.2607         1   0.3460    0.5214   0.2422
# 3    0.0332     0.0350    0.2146         1   0.3072    0.4596   0.2640
#
#    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0            30300               33888
# 1            39700             21941.5
# 3            45500               24097
#
# [3 rows x 27 columns]
# ('AL', 1)
#                          INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 2            Amridge University  Montgomery     AL   0.0      0.0        0.0
# 10  Birmingham Southern College  Birmingham     AL   0.0      0.0        0.0
# 12    Concordia College Alabama       Selma     AL   1.0      0.0        0.0
#
#     RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 2          1       NaN       NaN           1.0  ...     0.0000    0.0000
# 10         1     560.0     560.0           0.0  ...     0.0051    0.0000
# 12         1     420.0     400.0           0.0  ...     0.0031    0.0466
#
#     UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 2      0.2715    0.4536         1   0.6801    0.7795   0.8540
# 10     0.0051    0.0017         1   0.1920    0.4809   0.0152
# 12     0.0000    0.1056         1   0.8667    0.9333   0.2367
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2             40100               23370
# 10            44200               27000
# 12            19900   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('AR', 0)
#                                           INSTNM         CITY STABBR  HBCU  \
# 128        University of Arkansas at Little Rock  Little Rock     AR   0.0
# 129  University of Arkansas for Medical Sciences  Little Rock     AR   0.0
# 130                       ABC Beauty College Inc  Arkadelphia     AR   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 128      0.0        0.0         0     470.0     510.0           0.0  ...
# 129      0.0        0.0         0       NaN       NaN           0.0  ...
# 130      0.0        0.0         0       NaN       NaN           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 128     0.0755    0.0283     0.0003    0.4126         1   0.3941    0.4775
# 129     0.0281    0.0070     0.0169    0.2433         1   0.3944    0.6144
# 130     0.0000    0.0000     0.0000    0.2105         1   0.9815    1.0000
#
#      UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 128   0.4062              33900               21736
# 129   0.5133              61400               12500
# 130   0.4688  PrivacySuppressed               16500
#
# [3 rows x 27 columns]
# ('AR', 1)
#                                  INSTNM         CITY STABBR  HBCU  MENONLY  \
# 131            Arkansas Baptist College  Little Rock     AR   1.0      0.0
# 134                        Lyon College   Batesville     AR   0.0      0.0
# 144  Baptist Health College-Little Rock  Little Rock     AR   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 131        0.0         1       NaN       NaN           0.0  ...     0.0000
# 134        0.0         1     505.0     528.0           0.0  ...     0.0000
# 144        0.0         1       NaN       NaN           0.0  ...     0.0224
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 131    0.0089     0.0000    0.1127         1   0.8306    0.8695   0.2833
# 134    0.0333     0.0638    0.0101         1   0.4578    0.6740   0.0524
# 144    0.0000     0.0012    0.0848         1   0.5033    0.7266   0.3791
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 131            22000               38000
# 134            38600               25000
# 144            43200             13393.5
#
# [3 rows x 27 columns]
# ('AS', 0)
#                                 INSTNM       CITY STABBR  HBCU  MENONLY  \
# 4138  American Samoa Community College  Pago Pago     AS   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 4138        0.0         0       NaN       NaN           0.0  ...        0.0
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4138    0.0721     0.0024    0.4389         1   0.7245       0.0   0.1774
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4138            19800   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('AZ', 0)
#                                      INSTNM      CITY STABBR  HBCU  MENONLY  \
# 69                          Collins College   Phoenix     AZ   0.0      0.0
# 71              Empire Beauty School-Tucson    Tucson     AZ   0.0      0.0
# 72  Thunderbird School of Global Management  Glendale     AZ   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 69        0.0         0       NaN       NaN           0.0  ...     0.0241
# 71        0.0         0       NaN       NaN           0.0  ...     0.0000
# 72        0.0         0       NaN       NaN           0.0  ...     0.0000
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 69       0.0     0.3855    0.3373         0   0.7205    0.8228   0.4764
# 71       0.0     0.0079    0.2222         1   0.7962    0.6615   0.4229
# 72       0.0     0.0000    1.0000         0   0.0000    0.0000   0.0000
#
#     MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 69            25700               47000
# 71            18200                9833
# 72           118900   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('AZ', 1)
#                                   INSTNM     CITY STABBR  HBCU  MENONLY  \
# 68               Everest College-Phoenix  Phoenix     AZ   0.0      0.0
# 70  Empire Beauty School-Paradise Valley  Phoenix     AZ   0.0      0.0
# 73           American Indian College Inc  Phoenix     AZ   0.0      0.0
#
#     WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 68        0.0         1       NaN       NaN           0.0  ...     0.0373
# 70        0.0         1       NaN       NaN           0.0  ...     0.0400
# 73        0.0         1       NaN       NaN           0.0  ...     0.0000
#
#     UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 68       0.0     0.1026    0.4749         0   0.8291    0.7151   0.6700
# 70       0.0     0.0000    0.1600         0   0.6349    0.5873   0.4651
# 73       0.0     0.0000    0.0787         0   0.7500    0.5375   0.4684
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 68              28600                9500
# 70              17800                9588
# 73  PrivacySuppressed   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CA', 0)
#                                              INSTNM            CITY STABBR  \
# 192                       Academy of Art University   San Francisco     CA
# 193          ITT Technical Institute-Rancho Cordova  Rancho Cordova     CA
# 194  Academy of Chinese Culture and Health Sciences         Oakland     CA
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 192   0.0      0.0        0.0         0       NaN       NaN           0.0
# 193   0.0      0.0        0.0         0       NaN       NaN           0.0
# 194   0.0      0.0        0.0         0       NaN       NaN           0.0
#
#      ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 192  ...     0.0249    0.2523     0.2098    0.4334         1   0.4008
# 193  ...     0.0400    0.0000     0.1780    0.2540         0   0.7137
# 194  ...        NaN       NaN        NaN       NaN         1      NaN
#
#      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 192    0.5524   0.4043            36000               35093
# 193    0.7667   0.7235            38800             25827.5
# 194       NaN      NaN              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CA', 1)
#                                     INSTNM      CITY STABBR  HBCU  MENONLY  \
# 200  American Baptist Seminary of the West  Berkeley     CA   0.0      0.0
# 210               Azusa Pacific University     Azusa     CA   0.0      0.0
# 214                    Bethesda University   Anaheim     CA   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 200        0.0         1       NaN       NaN           0.0  ...        NaN
# 210        0.0         1     515.0     515.0           0.0  ...     0.0738
# 214        0.0         1       NaN       NaN           0.0  ...     0.0000
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 200       NaN        NaN       NaN         1      NaN       NaN      NaN
# 210    0.0191     0.0269    0.0875         1   0.2898    0.5172   0.1467
# 214    0.0115     0.0307    0.1609         1   0.3686    0.2078   0.4672
#
#        MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 200                NaN   PrivacySuppressed
# 210              50000               22500
# 214  PrivacySuppressed   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CO', 0)
#                                             INSTNM            CITY STABBR  \
# 565  The Salon Professional Academy-Grand Junction  Grand Junction     CO
# 566                         Adams State University         Alamosa     CO
# 567                         Aims Community College         Greeley     CO
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 565   0.0      0.0        0.0         0       NaN       NaN           0.0
# 566   0.0      0.0        0.0         0     475.0     509.0           0.0
# 567   0.0      0.0        0.0         0       NaN       NaN           0.0
#
#      ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 565  ...     0.0800    0.0000     0.0000    0.0000         1   0.3806
# 566  ...     0.0450    0.0000     0.0289    0.1474         1   0.5175
# 567  ...     0.0201    0.0005     0.0087    0.5246         1   0.4105
#
#      PCTFLOAN  UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 565    0.4925   0.2778  PrivacySuppressed                9570
# 566    0.6305   0.2106              32800               16255
# 567    0.3197   0.3941              31400                8773
#
# [3 rows x 27 columns]
# ('CO', 1)
#                                INSTNM         CITY STABBR  HBCU  MENONLY  \
# 575     Colorado Christian University     Lakewood     CO   0.0      0.0
# 589  Prince Institute-Rocky Mountains  Westminster     CO   0.0      0.0
# 592                   Denver Seminary    Littleton     CO   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 575        0.0         1       NaN       NaN           0.0  ...     0.0386
# 589        0.0         1       NaN       NaN           0.0  ...     0.0000
# 592        0.0         1       NaN       NaN           0.0  ...        NaN
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 575    0.0014     0.0369    0.5835         1   0.3087    0.5214   0.4500
# 589    0.0000     0.0000       NaN         0   0.6923    0.9487   0.8824
# 592       NaN        NaN       NaN         1      NaN       NaN      NaN
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 575            36900               25808
# 589            33400               20992
# 592              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('CT', 0)
#                                              INSTNM      CITY STABBR  HBCU  \
# 629                Paul Mitchell the School-Danbury   Danbury     CT   0.0
# 630                     Asnuntuck Community College   Enfield     CT   0.0
# 631  Branford Hall Career Institute-Branford Campus  Branford     CT   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 629      0.0        0.0         0       NaN       NaN           0.0  ...
# 630      0.0        0.0         0       NaN       NaN           0.0  ...
# 631      0.0        0.0         0       NaN       NaN           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 629     0.0292       0.0     0.0803    0.2774         1   0.4078    0.5475
# 630     0.0213       0.0     0.0319    0.4795         1   0.3790    0.0950
# 631     0.0142       0.0     0.0142    0.3002         1   0.7103    0.7351
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 629   0.2913            19000               10486
# 630   0.3959            30900                5500
# 631   0.5725            27900                9800
#
# [3 rows x 27 columns]
# ('CT', 1)
#                                  INSTNM       CITY STABBR  HBCU  MENONLY  \
# 628             Albertus Magnus College  New Haven     CT   0.0      0.0
# 645                Fairfield University  Fairfield     CT   0.0      0.0
# 652  Holy Apostles College and Seminary   Cromwell     CT   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 628        0.0         1       NaN       NaN           0.0  ...     0.0128
# 645        0.0         1       NaN       NaN           0.0  ...     0.0130
# 652        0.0         1       NaN       NaN           0.0  ...     0.0000
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 628    0.0088     0.0592    0.0825         1   0.4420    0.8002   0.5133
# 645    0.0234     0.0940    0.0406         1   0.1322    0.5092   0.0604
# 652    0.3966     0.0517    0.3621         1   0.1379    0.2241   0.7241
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 628            52100             27763.5
# 645            68500             26852.5
# 652              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('DC', 0)
#                                      INSTNM        CITY STABBR  HBCU  MENONLY  \
# 698  University of the District of Columbia  Washington     DC   1.0      0.0
# 700                    Gallaudet University  Washington     DC   0.0      0.0
# 701            George Washington University  Washington     DC   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 698        0.0         0       NaN       NaN           0.0  ...     0.0183
# 700        0.0         0     430.0     445.0           0.0  ...     0.0330
# 701        0.0         0     640.0     655.0           0.0  ...     0.0355
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 698    0.0336     0.1636    0.5554         1   0.5401    0.4832   0.5662
# 700    0.0819     0.0060    0.0500         1   0.5278    0.3880   0.2451
# 701    0.0945     0.0447    0.0666         1   0.1420    0.4003   0.0783
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 698            34800             22393.5
# 700            26000               17750
# 701            65400               25350
#
# [3 rows x 27 columns]
# ('DC', 1)
#                                                 INSTNM        CITY STABBR  \
# 696                                American University  Washington     DC
# 697                     Catholic University of America  Washington     DC
# 699  Pontifical Faculty of the Immaculate Conceptio...  Washington     DC
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 696   0.0      0.0        0.0         1     635.0     610.0           0.0
# 697   0.0      0.0        0.0         1     565.0     560.0           0.0
# 699   0.0      0.0        0.0         1       NaN       NaN           0.0
#
#      ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 696  ...     0.0541    0.0723     0.0562    0.0293         1   0.1666
# 697  ...     0.0394    0.0519     0.0646    0.0530         1   0.1252
# 699  ...        NaN       NaN        NaN       NaN         1      NaN
#
#      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 696    0.5213   0.0252            55900               24589
# 697    0.5615   0.0940            53900               26000
# 699       NaN      NaN              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('DE', 0)
#                                                 INSTNM        CITY STABBR  \
# 685  Margaret H Rollins School of Nursing at Beebe ...       Lewes     DE
# 686                          Dawn Career Institute Inc  Wilmington     DE
# 688         Delaware Technical Community College-Terry       Dover     DE
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 685   0.0      0.0        0.0         0       NaN       NaN           0.0
# 686   0.0      0.0        0.0         0       NaN       NaN           0.0
# 688   0.0      0.0        0.0         0       NaN       NaN           0.0
#
#      ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 685  ...     0.0000    0.0000     0.0000    0.0000         1   0.4545
# 686  ...     0.0796    0.0000     0.0000    0.0000         1   0.6677
# 688  ...     0.0328    0.0077     0.0142    0.5365         1   0.4606
#
#      PCTFLOAN  UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 685    0.4727   0.4909  PrivacySuppressed   PrivacySuppressed
# 686    0.7505   0.6003              22400                9500
# 688    0.2013   0.4075              30700                8000
#
# [3 rows x 27 columns]
# ('DE', 1)
#                                                 INSTNM        CITY STABBR  \
# 687         Delaware Technical Community College-Owens  Georgetown     DE
# 689  Delaware Technical Community College-Stanton/W...  Wilmington     DE
# 694                                     Wesley College       Dover     DE
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 687   0.0      0.0        0.0         1       NaN       NaN           0.0
# 689   0.0      0.0        0.0         1       NaN       NaN           0.0
# 694   0.0      0.0        0.0         1     430.0     430.0           0.0
#
#      ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 687  ...     0.0259    0.0283     0.0080    0.5327         1   0.4674
# 689  ...     0.0258    0.0202     0.0151    0.6461         1   0.3511
# 694  ...     0.0391    0.0007     0.0482    0.0342         1   0.5010
#
#      PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 687    0.1411   0.3561            28800                6750
# 689    0.1504   0.3842            34000                7508
# 694    0.8632   0.1319            41600               31000
#
# [3 rows x 27 columns]
# ('FL', 0)
#                                    INSTNM             CITY STABBR  HBCU  \
# 709                       Wyotech-Daytona     Ormond Beach     FL   0.0
# 710  The Art Institute of Fort Lauderdale  Fort Lauderdale     FL   0.0
# 711            Atlantic Technical College    Coconut Creek     FL   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 709      0.0        0.0         0       NaN       NaN           0.0  ...
# 710      0.0        0.0         0       NaN       NaN           0.0  ...
# 711      0.0        0.0         0       NaN       NaN           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 709     0.0325    0.0000     0.0075    0.0000         1   0.6402    0.6978
# 710     0.0007    0.0007     0.2734    0.3692         1   0.6263    0.7942
# 711     0.0123    0.0000     0.0000    0.0000         1   0.1363    0.0000
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 709   0.5980            31800               11600
# 710   0.4132            28800               29983
# 711   0.5044            31900   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('FL', 1)
#                                     INSTNM         CITY STABBR  HBCU  MENONLY  \
# 712         The Baptist College of Florida   Graceville     FL   0.0      0.0
# 713                       Barry University        Miami     FL   0.0      0.0
# 714  Gooding Institute of Nurse Anesthesia  Panama City     FL   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 712        0.0         1     545.0     465.0           0.0  ...     0.0308
# 713        0.0         1     470.0     462.0           0.0  ...     0.0164
# 714        0.0         1       NaN       NaN           0.0  ...        NaN
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 712    0.0000     0.0507    0.2291         1   0.5878    0.5602   0.3531
# 713    0.0741     0.0841    0.1518         1   0.5045    0.6733   0.4361
# 714       NaN        NaN       NaN         0      NaN       NaN      NaN
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 712            30800               20052
# 713            44100               28250
# 714              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('FM', 0)
#                          INSTNM     CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4214  College of Micronesia-FSM  Pohnpei     FM   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4214         0       NaN       NaN           0.0  ...        0.0       0.0
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4214     0.0115    0.3157         1   0.8778       0.0   0.1631
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4214            15700   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('GA', 0)
#                                          INSTNM      CITY STABBR  HBCU  \
# 860        Abraham Baldwin Agricultural College    Tifton     GA   0.0
# 862  Interactive College of Technology-Chamblee  Chamblee     GA   0.0
# 863    Interactive College of Technology-Morrow    Morrow     GA   0.0
#
#      MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 860      0.0        0.0         0     465.0     460.0           0.0  ...
# 862      0.0        0.0         0       NaN       NaN           0.0  ...
# 863      0.0        0.0         0       NaN       NaN           0.0  ...
#
#      UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 860     0.0092    0.0151     0.0003    0.2441         1   0.4629    0.4493
# 862     0.0000    0.0000     0.0000    0.0174         1   0.5620    0.4236
# 863     0.0000    0.0000     0.0000    0.0000         1   0.6129    0.6452
#
#      UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 860   0.1523            32000             15085.5
# 862   0.7937            21100                7376
# 863   0.7778            21100                7376
#
# [3 rows x 27 columns]
# ('GA', 1)
#                                 INSTNM      CITY STABBR  HBCU  MENONLY  \
# 785  Luther Rice University & Seminary  Lithonia     GA   0.0      0.0
# 861                Agnes Scott College   Decatur     GA   0.0      0.0
# 867                     Andrew College  Cuthbert     GA   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 785        0.0         1       NaN       NaN           0.0  ...     0.0000
# 861        1.0         1       NaN       NaN           0.0  ...     0.0636
# 867        0.0         1     380.0     380.0           0.0  ...     0.0305
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 785    0.0020     0.0020    0.8224         1   0.5832    0.5362   0.8748
# 861    0.0898     0.0249    0.0050         1   0.4404    0.6470   0.0459
# 867    0.0271     0.0000    0.0034         1   0.6139    0.8544   0.0095
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 785            39400               29500
# 861            38800               27000
# 867            27500               12875
#
# [3 rows x 27 columns]
# ('GU', 0)
#                       INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4139  Guam Community College  Mangilao     GU   0.0      0.0        0.0
# 4140      University of Guam  Mangilao     GU   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4139         0       NaN       NaN           0.0  ...        0.0     0.007
# 4140         0       NaN       NaN           0.0  ...        0.0     0.008
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4139     0.0055    0.5453         1   0.6354     0.000   0.3058
# 4140     0.0230    0.2265         1   0.5269     0.276   0.2064
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4139            22000   PrivacySuppressed
# 4140            29900   PrivacySuppressed
#
# [2 rows x 27 columns]
# ('GU', 1)
#                           INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 5289  Pacific Islands University  Mangilao     GU   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 5289         1       NaN       NaN           0.0  ...        0.0       0.0
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 5289        0.0    0.1846         1    0.973       0.0   0.2533
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 5289  PrivacySuppressed   PrivacySuppressed
#
# [1 rows x 27 columns]
# ('HI', 0)
#                               INSTNM      CITY STABBR  HBCU  MENONLY  \
# 951     University of Hawaii at Hilo      Hilo     HI   0.0      0.0
# 952    University of Hawaii at Manoa  Honolulu     HI   0.0      0.0
# 953  Hawaii Institute of Hair Design  Honolulu     HI   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 951        0.0         0     465.0     475.0           0.0  ...     0.2983
# 952        0.0         0     530.0     555.0           0.0  ...     0.2516
# 953        0.0         0       NaN       NaN           0.0  ...     0.0988
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 951    0.0476     0.0027    0.1733         1   0.4706    0.4515   0.2690
# 952    0.0253     0.0018    0.1601         1   0.3015    0.3746   0.1755
# 953    0.0000     0.0000    0.0000         1   0.8112    0.3776   0.5529
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 951            33500               19197
# 952            43000               19000
# 953            17300                5868
#
# [3 rows x 27 columns]
# ('HI', 1)
#                                 INSTNM      CITY STABBR  HBCU  MENONLY  \
# 949             Heald College-Honolulu  Honolulu     HI   0.0      0.0
# 950   Chaminade University of Honolulu  Honolulu     HI   0.0      0.0
# 3805   Brigham Young University-Hawaii      Laie     HI   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 949         0.0         1       NaN       NaN           0.0  ...     0.1406
# 950         0.0         1     470.0     480.0           0.0  ...     0.1145
# 3805        0.0         1     525.0     545.0           0.0  ...     0.0817
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 949     0.0000     0.2648    0.2198         0   0.7283    0.6920   0.5262
# 950     0.0169     0.1299    0.1765         1   0.4641    0.4425   0.3237
# 3805    0.3616     0.0008    0.0523         1   0.2415    0.1749   0.2224
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 949             35000               11676
# 950             38400               22000
# 3805            41500                8291
#
# [3 rows x 27 columns]
# ('IA', 0)
#                        INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 1247            Allen College    Waterloo     IA   0.0      0.0        0.0
# 1248  AIB College of Business  Des Moines     IA   0.0      0.0        0.0
# 1251    Capri College-Dubuque     Dubuque     IA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 1247         0       NaN       NaN           0.0  ...     0.0079    0.0079
# 1248         0       NaN       NaN           0.0  ...     0.0128    0.0198
# 1251         0       NaN       NaN           0.0  ...     0.0159    0.0000
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 1247     0.0501    0.3588         1   0.3317    0.8065   0.3945
# 1248     0.4140    0.2490         1   0.4132    0.7125   0.3209
# 1251     0.0000    0.0000         1   0.4845    0.5103   0.2295
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1247            49100             17090.5
# 1248            37000             19732.5
# 1251            19400                8477
#
# [3 rows x 27 columns]
# ('IA', 1)
#                                             INSTNM          CITY STABBR  HBCU  \
# 1249                        Briar Cliff University    Sioux City     IA   0.0
# 1250                        Buena Vista University    Storm Lake     IA   0.0
# 1253  American College of Hairstyling-Cedar Rapids  Cedar Rapids     IA   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 1249      0.0        0.0         1     475.0     510.0           0.0  ...
# 1250      0.0        0.0         1     435.0     478.0           0.0  ...
# 1253      0.0        0.0         1       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 1249     0.0187    0.0353     0.0000    0.1971         1   0.4549    0.7975
# 1250     0.0100    0.0264     0.0724    0.1147         1   0.4911    0.8195
# 1253     0.0000    0.0000     0.0000    0.0000         0   0.8889    0.8889
#
#       UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1249   0.2380              38100               24000
# 1250   0.3999              38300             23877.5
# 1253   0.4545  PrivacySuppressed   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('ID', 0)
#                               INSTNM         CITY STABBR  HBCU  MENONLY  \
# 965         Carrington College-Boise        Boise     ID   0.0      0.0
# 967           Boise State University        Boise     ID   0.0      0.0
# 968  Eastern Idaho Technical College  Idaho Falls     ID   0.0      0.0
#
#      WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 965        0.0         0       NaN       NaN           0.0  ...     0.0243
# 967        0.0         0     510.0     515.0           0.0  ...     0.0353
# 968        0.0         0       NaN       NaN           0.0  ...     0.0000
#
#      UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 965    0.0000     0.0061    0.0789         1   0.6654    0.5804   0.5580
# 967    0.0408     0.0228    0.2519         1   0.3464    0.4669   0.3182
# 968    0.0000     0.0074    0.5037         1   0.5421    0.5393   0.6041
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 965            25000                9500
# 967            35600               23500
# 968            26600               11375
#
# [3 rows x 27 columns]
# ('ID', 1)
#                              INSTNM     CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 966             Boise Bible College    Boise     ID   0.0      0.0        0.0
# 977   Northwest Nazarene University    Nampa     ID   0.0      0.0        0.0
# 979  Brigham Young University-Idaho  Rexburg     ID   0.0      0.0        0.0
#
#      RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 966         1     520.0     480.0           0.0  ...     0.0174    0.0058
# 977         1     525.0     515.0           0.0  ...     0.0177    0.0231
# 979         1     515.0     505.0           0.0  ...     0.0569    0.0659
#
#      UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 966     0.0233    0.0930         1   0.6793    0.6576   0.1613
# 977     0.0723    0.1085         1   0.3382    0.6081   0.2991
# 979     0.0238    0.3462         1   0.4733    0.2138   0.3710
#
#      MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 966            25500               19596
# 977            35900               25500
# 979            38800               11000
#
# [3 rows x 27 columns]
# ('IL', 0)
#                                              INSTNM          CITY STABBR  \
# 43                       Prince Institute-Southeast      Elmhurst     IL
# 981                                Adler University       Chicago     IL
# 982  Alvareitas College of Cosmetology-Edwardsville  Edwardsville     IL
#
#      HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 43    0.0      0.0        0.0         0       NaN       NaN           0.0
# 981   0.0      0.0        0.0         0       NaN       NaN           0.0
# 982   0.0      0.0        0.0         0       NaN       NaN           0.0
#
#      ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 43   ...        0.0       0.0        0.0    0.0000         1   0.7857
# 981  ...        NaN       NaN        NaN       NaN         1      NaN
# 982  ...        0.0       0.0        0.0    0.3404         0   0.6364
#
#      PCTFLOAN  UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 43     0.9375   0.6569  PrivacySuppressed               20992
# 981       NaN      NaN                NaN   PrivacySuppressed
# 982    0.7792   0.3111  PrivacySuppressed                9911
#
# [3 rows x 27 columns]
# ('IL', 1)
#                                      INSTNM         CITY STABBR  HBCU  \
# 986                       Augustana College  Rock Island     IL   0.0
# 992                       Blackburn College  Carlinville     IL   0.0
# 1004  Catholic Theological Union at Chicago      Chicago     IL   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 986       0.0        0.0         1       NaN       NaN           0.0  ...
# 992       0.0        0.0         1     473.0     488.0           0.0  ...
# 1004      0.0        0.0         1       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 986      0.0373    0.0251     0.0194    0.0061         1   0.2310    0.6985
# 992      0.0208    0.0000     0.0104    0.0433         1   0.5064    0.7937
# 1004        NaN       NaN        NaN       NaN         1      NaN       NaN
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 986    0.0115            47900               27000
# 992    0.0534            37100               26000
# 1004      NaN              NaN   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('IN', 0)
#                                INSTNM          CITY STABBR  HBCU  MENONLY  \
# 1165  Apex Academy of Hair Design Inc      Anderson     IN   0.0      0.0
# 1166            Ball State University        Muncie     IN   0.0      0.0
# 1168                Butler University  Indianapolis     IN   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 1165        0.0         0       NaN       NaN           0.0  ...     0.0000
# 1166        0.0         0     550.0     545.0           0.0  ...     0.0247
# 1168        0.0         0     580.0     590.0           0.0  ...     0.0214
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 1165    0.0000     0.0000    0.0000         1   0.5000    0.3333   0.3333
# 1166    0.0196     0.0127    0.0618         1   0.3399    0.5917   0.0715
# 1168    0.0232     0.0294    0.0135         1   0.1649    0.5742   0.0185
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1165  PrivacySuppressed   PrivacySuppressed
# 1166              38800               25000
# 1168              55000               27000
#
# [3 rows x 27 columns]
# ('IN', 1)
#                             INSTNM       CITY STABBR  HBCU  MENONLY  \
# 990   Bethany Theological Seminary   Richmond     IN   0.0      0.0
# 1163               Ancilla College  Donaldson     IN   0.0      0.0
# 1164           Anderson University   Anderson     IN   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 990         0.0         1       NaN       NaN           0.0  ...        NaN
# 1163        0.0         1       NaN       NaN           0.0  ...     0.0291
# 1164        0.0         1     515.0     515.0           0.0  ...     0.0104
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 990        NaN        NaN       NaN         1      NaN       NaN      NaN
# 1163    0.0053     0.0000    0.1878         1   0.6900    0.7400   0.2925
# 1164    0.0306     0.0644    0.0863         1   0.2118    0.4688   0.1215
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 990               NaN   PrivacySuppressed
# 1163            29400               17000
# 1164            35600               27000
#
# [3 rows x 27 columns]
# ('KS', 0)
#                                 INSTNM        CITY STABBR  HBCU  MENONLY  \
# 1326    Allen County Community College        Iola     KS   0.0      0.0
# 1328   Barton County Community College  Great Bend     KS   0.0      0.0
# 1332  Brown Mackie College-Kansas City      Lenexa     KS   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 1326        0.0         0       NaN       NaN           0.0  ...     0.0004
# 1328        0.0         0       NaN       NaN           0.0  ...     0.0212
# 1332        0.0         0       NaN       NaN           0.0  ...     0.0000
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 1326    0.0011     0.0046    0.5441         1   0.4001    0.2703   0.2886
# 1328    0.0000     0.0185    0.3534         1   0.1424    0.0922   0.4148
# 1332    0.0000     0.0197    0.0000         1   0.6440    0.6975   0.6296
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1326            29100                6900
# 1328            32200                8976
# 1332            25200               16000
#
# [3 rows x 27 columns]
# ('KS', 1)
#                    INSTNM          CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 1327     Baker University  Baldwin City     KS   0.0      0.0        0.0
# 1329  Benedictine College      Atchison     KS   0.0      0.0        0.0
# 1330      Bethany College     Lindsborg     KS   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 1327         1     478.0     505.0           0.0  ...     0.0115    0.0127
# 1329         1     565.0     530.0           0.0  ...     0.0419    0.0310
# 1330         1     435.0     470.0           0.0  ...     0.0251    0.0031
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 1327     0.0667    0.3511         1   0.3774    0.7296   0.4418
# 1329     0.0283    0.0060         1   0.2073    0.5367   0.0208
# 1330     0.0000    0.0126         1   0.3988    0.1533   0.0316
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1327            48800               25250
# 1329            39600               26000
# 1330            38100               27000
#
# [3 rows x 27 columns]
# ('KY', 0)
#                                        INSTNM          CITY STABBR  HBCU  \
# 1389                      Alice Lloyd College  Pippa Passes     KY   0.0
# 1390                        Asbury University       Wilmore     KY   0.0
# 1392  Ashland Community and Technical College       Ashland     KY   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 1389      0.0        0.0         0     455.0     485.0           0.0  ...
# 1390      0.0        0.0         0     559.0     551.0           0.0  ...
# 1392      0.0        0.0         0       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 1389     0.0015    0.0015     0.0107    0.0457         1   0.5737    0.6815
# 1390     0.0620    0.0167     0.0427    0.1741         1   0.3316    0.7001
# 1392     0.0115    0.0000     0.0058    0.3288         1   0.5259    0.4076
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1389   0.0460            33500               16495
# 1390   0.1448            33600               25250
# 1392   0.3974            23700               11780
#
# [3 rows x 27 columns]
# ('KY', 1)
#                            INSTNM        CITY STABBR  HBCU  MENONLY  \
# 1391  Asbury Theological Seminary     Wilmore     KY   0.0      0.0
# 1394        Bellarmine University  Louisville     KY   0.0      0.0
# 1398           Brescia University   Owensboro     KY   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 1391        0.0         1       NaN       NaN           0.0  ...        NaN
# 1394        0.0         1     550.0     545.0           0.0  ...     0.0344
# 1398        0.0         1     460.0     490.0           0.0  ...     0.0000
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 1391       NaN        NaN       NaN         1      NaN       NaN      NaN
# 1394    0.0108     0.0164    0.0536         1   0.2364    0.6213   0.0941
# 1398    0.0100     0.1147    0.2403         1   0.4989    0.8219   0.4903
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1391            42500   PrivacySuppressed
# 1394            46600               25000
# 1398            37500               30500
#
# [3 rows x 27 columns]
# ('LA', 0)
#                                              INSTNM        CITY STABBR  HBCU  \
# 1461  Central Louisiana Technical Community College  Alexandria     LA   0.0
# 1462                    American School of Business  Shreveport     LA   0.0
# 1463                           Ayers Career College  Shreveport     LA   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 1461      0.0        0.0         0       NaN       NaN           0.0  ...
# 1462      0.0        0.0         0       NaN       NaN           0.0  ...
# 1463      0.0        0.0         0       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 1461     0.0155     0.003     0.0569    0.3929         1   0.3466    0.0000
# 1462     0.0164     0.000     0.0000    0.2951         0   0.6032    0.5159
# 1463     0.0039     0.000     0.0000    0.0000         1   0.9108    0.8410
#
#       UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1461   0.4799  PrivacySuppressed   PrivacySuppressed
# 1462   0.8353              19400                9500
# 1463   0.6816              25100                9500
#
# [3 rows x 27 columns]
# ('LA', 1)
#                               INSTNM         CITY STABBR  HBCU  MENONLY  \
# 1470  Centenary College of Louisiana   Shreveport     LA   0.0      0.0
# 1478              Dillard University  New Orleans     LA   1.0      0.0
# 1492               Louisiana College    Pineville     LA   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 1470        0.0         1     530.0     520.0           0.0  ...     0.0383
# 1478        0.0         1     440.0     430.0           0.0  ...     0.0075
# 1492        0.0         1       NaN       NaN           0.0  ...     0.0115
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 1470    0.0201     0.0000    0.0091         1   0.3515    0.6092   0.0307
# 1478    0.0217     0.0392    0.0517         1   0.7422    0.8833   0.0904
# 1492    0.0533     0.0136    0.0408         1   0.4319    0.5896   0.1487
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1470            40400               25000
# 1478            32800               35000
# 1492            39100             23743.5
#
# [3 rows x 27 columns]
# ('MA', 0)
#                                            INSTNM         CITY STABBR  HBCU  \
# 1619           Hult International Business School    Cambridge     MA   0.0
# 1620  New England College of Business and Finance       Boston     MA   0.0
# 1621               American International College  Springfield     MA   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 1619      0.0        0.0         0       NaN       NaN           0.0  ...
# 1620      0.0        0.0         0       NaN       NaN           1.0  ...
# 1621      0.0        0.0         0     438.0     443.0           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 1619        NaN       NaN        NaN       NaN         1      NaN       NaN
# 1620     0.0000    0.0000     0.7290    0.7696         1   0.2574    0.4426
# 1621     0.0448    0.0027     0.1473    0.0659         1   0.5063    0.8480
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 1619      NaN              NaN   PrivacySuppressed
# 1620   0.8543              NaN               18450
# 1621   0.2102            38900               27000
#
# [3 rows x 27 columns]
# ('MA', 1)
#                                  INSTNM           CITY STABBR  HBCU  MENONLY  \
# 1623  Andover Newton Theological School  Newton Centre     MA   0.0      0.0
# 1624                 Anna Maria College         Paxton     MA   0.0      0.0
# 1626                 Assumption College      Worcester     MA   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 1623        0.0         1       NaN       NaN           0.0  ...        NaN
# 1624        0.0         1       NaN       NaN           0.0  ...     0.0208
# 1626        0.0         1       NaN       NaN           0.0  ...     0.0223
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# ...
# ('UT', 0)
#                                       INSTNM         CITY STABBR  HBCU  \
# 3802                 AmeriTech College-Provo        Provo     UT   0.0
# 3803  Bridgerland Applied Technology College        Logan     UT   0.0
# 3806        Broadview University-West Jordan  West Jordan     UT   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 3802      0.0        0.0         0       NaN       NaN           0.0  ...
# 3803      0.0        0.0         0       NaN       NaN           0.0  ...
# 3806      0.0        0.0         0       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 3802     0.0153       0.0     0.0458    0.0000         1   0.7295    0.8074
# 3803     0.0107       0.0     0.0253    0.6525         1   0.2017    0.0000
# 3806     0.0102       0.0     0.0508    0.3452         1   0.6943    0.8035
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3802   0.3526            24700               24370
# 3803   0.4148            24300   PrivacySuppressed
# 3806   0.5590            25500               28458
#
# [3 rows x 27 columns]
# ('UT', 1)
#                                   INSTNM              CITY STABBR  HBCU  \
# 3804      Brigham Young University-Provo             Provo     UT   0.0
# 3817  Latter-day Saints Business College    Salt Lake City     UT   0.0
# 3818      Everest College-Salt Lake City  West Valley City     UT   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 3804      0.0        0.0         1     630.0     630.0           0.0  ...
# 3817      0.0        0.0         1       NaN       NaN           0.0  ...
# 3818      0.0        0.0         1       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 3804     0.0344    0.0314     0.0118    0.0981         1   0.3702    0.1921
# 3817     0.0429    0.1775     0.0100    0.3365         1   0.3319    0.2144
# 3818     0.0230    0.0000     0.0876    0.2811         0   0.7030    0.5619
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3804   0.1220            57200               11000
# 3817   0.2235            35100                5799
# 3818   0.5371            24400             10632.5
#
# [3 rows x 27 columns]
# ('VA', 0)
#                                 INSTNM            CITY STABBR  HBCU  MENONLY  \
# 704                  Medtech Institute    Falls Church     VA   0.0      0.0
# 3850  Bar Palma Beauty Careers Academy         Roanoke     VA   0.0      0.0
# 3851     Advanced Technology Institute  Virginia Beach     VA   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 704         0.0         0       NaN       NaN           0.0  ...     0.0372
# 3850        0.0         0       NaN       NaN           0.0  ...     0.0000
# 3851        0.0         0       NaN       NaN           0.0  ...     0.0153
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 704        0.0     0.0066    0.0000         1   0.7097    0.4198   0.2039
# 3850       0.0     0.0423    0.1831         1   0.4367    0.4177   0.6944
# 3851       0.0     0.0042    0.0000         1   0.3374    0.3010   0.5364
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 704             26300                9236
# 3850            16900                9731
# 3851            38000               16279
#
# [3 rows x 27 columns]
# ('VA', 1)
#                    INSTNM         CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 3852   Averett University     Danville     VA   0.0      0.0        0.0
# 3853    Bluefield College    Bluefield     VA   0.0      0.0        0.0
# 3854  Bridgewater College  Bridgewater     VA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 3852         1     460.0     469.0           0.0  ...     0.0000    0.0502
# 3853         1     450.0     455.0           0.0  ...     0.0334    0.0212
# 3854         1     520.0     525.0           0.0  ...     0.0464    0.0074
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3852     0.0048    0.0227         1   0.5120    0.7879   0.0992
# 3853     0.0145    0.1193         1   0.4540    0.6989   0.4241
# 3854     0.0317    0.0051         1   0.2754    0.7348   0.0114
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3852            42400               25000
# 3853            40000               18873
# 3854            40800               27000
#
# [3 rows x 27 columns]
# ('VI', 0)
#                                 INSTNM              CITY STABBR  HBCU  \
# 4216  University of the Virgin Islands  Charlotte Amalie     VI   1.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 4216      0.0        0.0         0     400.0     390.0           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 4216     0.0101    0.0589     0.0715    0.3059         1   0.5161    0.3224
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4216   0.3196            31800               15150
#
# [1 rows x 27 columns]
# ('VI', 1)
#                                                 INSTNM       CITY STABBR  \
# 7404  University of the Virgin Islands-Albert A. Sheen  St. Croix     VI
#
#       HBCU  MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  \
# 7404   NaN      NaN        NaN         1       NaN       NaN           NaN
#
#       ...  UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  \
# 7404  ...        NaN       NaN        NaN       NaN         1      NaN
#
#       PCTFLOAN  UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 7404       NaN      NaN            31800               15150
#
# [1 rows x 27 columns]
# ('VT', 0)
#                     INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 3829    Bennington College  Bennington     VT   0.0      0.0        0.0
# 3830    Burlington College  Burlington     VT   0.0      0.0        0.0
# 3831  Castleton University   Castleton     VT   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 3829         0       NaN       NaN           0.0  ...     0.0349    0.1284
# 3830         0       NaN       NaN           0.0  ...     0.0225    0.0169
# 3831         0     480.0     490.0           0.0  ...     0.0153    0.0169
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3829      0.038    0.0048         1   0.2342    0.5703   0.0097
# 3830      0.118    0.0843         0   0.4670    0.7123   0.2545
# 3831      0.063    0.0910         1   0.2938    0.6399   0.0938
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3829            24600               27000
# 3830            26000               25000
# 3831            34900               25000
#
# [3 rows x 27 columns]
# ('VT', 1)
#                        INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 3835   Green Mountain College    Poultney     VT   0.0      0.0        0.0
# 3843  Saint Michael's College  Colchester     VT   0.0      0.0        0.0
# 3845     College of St Joseph     Rutland     VT   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 3835         1       NaN       NaN           0.0  ...     0.0090    0.0323
# 3843         1       NaN       NaN           0.0  ...     0.0191    0.0280
# 3845         1       NaN       NaN           0.0  ...     0.0000    0.0087
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3835     0.2527    0.0197         1   0.3847    0.7051   0.0407
# 3843     0.0015    0.0108         1   0.1682    0.6456   0.0220
# 3845     0.0000    0.1000         1   0.6193    0.7216   0.2557
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3835            30100               25449
# 3843            46600               27400
# 3845            34700               24127
#
# [3 rows x 27 columns]
# ('WA', 0)
#                                             INSTNM       CITY STABBR  HBCU  \
# 3943                                Beauty Academy  Wenatchee     WA   0.0
# 3944                  The Art Institute of Seattle    Seattle     WA   0.0
# 3945  Evergreen Beauty and Barber College-Bellevue   Bellevue     WA   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 3943      0.0        0.0         0       NaN       NaN           0.0  ...
# 3944      0.0        0.0         0       NaN       NaN           0.0  ...
# 3945      0.0        0.0         0       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 3943     0.0294       0.0     0.0000    0.0000         1   0.6385    0.6154
# 3944     0.0000       0.0     0.8149    0.3128         1   0.4272    0.6662
# 3945     0.0444       0.0     0.0778    0.0000         1   0.3314    0.3314
#
#       UG25ABV    MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3943   0.3896  PrivacySuppressed              8718.5
# 3944   0.3795              34100             25937.5
# 3945   0.4400  PrivacySuppressed                7917
#
# [3 rows x 27 columns]
# ('WA', 1)
#                         INSTNM      CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 3967        Gonzaga University   Spokane     WA   0.0      0.0        0.0
# 3981  Trinity Lutheran College   Everett     WA   0.0      0.0        0.0
# 3985      Northwest University  Kirkland     WA   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 3967         1     590.0     605.0           0.0  ...     0.0541     0.028
# 3981         1       NaN       NaN           0.0  ...     0.0048     0.000
# 3985         1     517.0     496.0           0.0  ...     0.0447     0.020
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 3967     0.0320    0.0128         1   0.1832    0.5155   0.0298
# 3981     0.0144    0.0478         0   0.4948    0.7010   0.2165
# 3985     0.0461    0.1239         1   0.3790    0.6787   0.3067
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 3967            53000               25500
# 3981            37100               25000
# 3985            37700             23724.5
#
# [3 rows x 27 columns]
# ('WI', 0)
#                                           INSTNM        CITY STABBR  HBCU  \
# 4063  Advanced Institute of Hair Design-Glendale    Glendale     WI   0.0
# 4064                        VICI Aveda Institute  Greenfield     WI   0.0
# 4066              Madison Area Technical College     Madison     WI   0.0
#
#       MENONLY  WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  \
# 4063      0.0        0.0         0       NaN       NaN           0.0  ...
# 4064      0.0        0.0         0       NaN       NaN           0.0  ...
# 4066      0.0        0.0         0       NaN       NaN           0.0  ...
#
#       UGDS_2MOR  UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  \
# 4063     0.0244    0.0000     0.0000    0.0000         1   0.5089    0.5325
# 4064     0.0400    0.0000     0.0240    0.0000         1   0.5069    0.6406
# 4066     0.0390    0.0165     0.0096    0.6223         1   0.3259    0.3565
#
#       UG25ABV  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4063   0.1736            24000               10314
# 4064   0.2059            24000               10314
# 4066   0.5080            35000               14250
#
# [3 rows x 27 columns]
# ('WI', 1)
#                            INSTNM       CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4065              Alverno College  Milwaukee     WI   0.0      0.0        1.0
# 4070  Cardinal Stritch University  Milwaukee     WI   0.0      0.0        0.0
# 4071           Carroll University   Waukesha     WI   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4065         1       NaN       NaN           0.0  ...     0.0308    0.0053
# 4070         1     465.0     480.0           0.0  ...     0.0239    0.0421
# 4071         1     527.0     542.0           0.0  ...     0.0208    0.0119
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4065     0.0000    0.2481         1   0.6096    0.8743   0.3464
# 4070     0.0269    0.0638         1   0.4278    0.7356   0.6632
# 4071     0.0041    0.0838         1   0.2709    0.7137   0.1119
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4065            37100             32606.5
# 4070            48500               27000
# 4071            41300               27000
#
# [3 rows x 27 columns]
# ('WV', 0)
#                                      INSTNM       CITY STABBR  HBCU  MENONLY  \
# 2842           Scott College of Cosmetology   Wheeling     WV   0.0      0.0
# 4019  B M Spurr School of Practical Nursing  Glen Dale     WV   0.0      0.0
# 4020             Ben Franklin Career Center     Dunbar     WV   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 2842        0.0         0       NaN       NaN           0.0  ...     0.0519
# 4019        0.0         0       NaN       NaN           0.0  ...     0.0000
# 4020        0.0         0       NaN       NaN           0.0  ...     0.0023
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 2842       0.0        0.0    0.0000         1   0.5276    0.4961   0.1111
# 4019       0.0        0.0    0.0000         1   0.4722    0.0000   0.4444
# 4020       0.0        0.0    0.7885         1   0.1761    0.0000   0.7568
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 2842              14800                9250
# 4019  PrivacySuppressed   PrivacySuppressed
# 4020              20800   PrivacySuppressed
#
# [3 rows x 27 columns]
# ('WV', 1)
#                             INSTNM        CITY STABBR  HBCU  MENONLY  \
# 4016  Alderson Broaddus University    Philippi     WV   0.0      0.0
# 4018     Appalachian Bible College  Mount Hope     WV   0.0      0.0
# 4027        Davis & Elkins College      Elkins     WV   0.0      0.0
#
#       WOMENONLY  RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  \
# 4016        0.0         1     475.0     485.0           0.0  ...     0.0098
# 4018        0.0         1     514.0     487.0           0.0  ...     0.0000
# 4027        0.0         1     485.0     490.0           0.0  ...     0.0000
#
#       UGDS_NRA  UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4016    0.0342     0.0020    0.0342         1   0.4800    0.8945   0.0722
# 4018    0.0051     0.0000    0.0612         1   0.4388    0.2770   0.0899
# 4027    0.1466     0.1657    0.0167         1   0.4188    0.6579   0.1133
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4016            46000               27000
# 4018            28700                9300
# 4027            35000             23840.5
#
# [3 rows x 27 columns]
# ('WY', 0)
#                        INSTNM        CITY STABBR  HBCU  MENONLY  WOMENONLY  \
# 4128           Casper College      Casper     WY   0.0      0.0        0.0
# 4129  Central Wyoming College    Riverton     WY   0.0      0.0        0.0
# 4130  Eastern Wyoming College  Torrington     WY   0.0      0.0        0.0
#
#       RELAFFIL  SATVRMID  SATMTMID  DISTANCEONLY  ...  UGDS_2MOR  UGDS_NRA  \
# 4128         0       NaN       NaN           0.0  ...     0.0163    0.0078
# 4129         0       NaN       NaN           0.0  ...     0.0300    0.0073
# 4130         0       NaN       NaN           0.0  ...     0.0088    0.0015
#
#       UGDS_UNKN  PPTUG_EF  CURROPER  PCTPELL  PCTFLOAN  UG25ABV  \
# 4128     0.0269    0.3250         1   0.2188    0.1455   0.3447
# 4129     0.0173    0.4377         1   0.1700    0.0967   0.3992
# 4130     0.0000    0.3275         1   0.1729    0.1166   0.2371
#
#       MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 4128            34800               10764
# 4129            25200                8757
# 4130            25900               10000
#
# [3 rows x 27 columns]

# %%
for name, group in grouped:
    print(name)
    display(group)
    break
# Out:
# ('AK', 0)
#                                       INSTNM       CITY  ... MD_EARN_WNE_P10  \
# 60            University of Alaska Anchorage  Anchorage  ...           42500
# 62            University of Alaska Fairbanks  Fairbanks  ...           36200
# 63            University of Alaska Southeast     Juneau  ...           37400
# 65    AVTEC-Alaska's Institute of Technology     Seward  ...           33500
# 66                 Charter College-Anchorage  Anchorage  ...           39200
# 67                     Alaska Career College  Anchorage  ...           28700
# 5171                       Ilisagvik College     Barrow  ...           24900
#
#       GRAD_DEBT_MDN_SUPP
# 60               19449.5
# 62                 19355
# 63                 16875
# 65     PrivacySuppressed
# 66                 13875
# 67                  8994
# 5171   PrivacySuppressed
#
# [7 rows x 27 columns]

# %%
grouped.head(1)
# Out:
#                                                 INSTNM        CITY  ...  \
# 0                             Alabama A & M University      Normal  ...
# 2                                   Amridge University  Montgomery  ...
# 43                          Prince Institute-Southeast    Elmhurst  ...
# 60                      University of Alaska Anchorage   Anchorage  ...
# 61                                Alaska Bible College      Palmer  ...
# ...                                                ...         ...  ...
# 4561                   College of the Marshall Islands      Majuro  ...
# 5289                        Pacific Islands University    Mangilao  ...
# 6439                           Touro University Nevada   Henderson  ...
# 7404  University of the Virgin Islands-Albert A. Sheen   St. Croix  ...
# 7419                 Computer Career Center-Las Cruces  Las Cruces  ...
#
#         MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# 0                 30300               33888
# 2                 40100               23370
# 43    PrivacySuppressed               20992
# 60                42500             19449.5
# 61                  NaN   PrivacySuppressed
# ...                 ...                 ...
# 4561  PrivacySuppressed   PrivacySuppressed
# 5289  PrivacySuppressed   PrivacySuppressed
# 6439                NaN   PrivacySuppressed
# 7404              31800               15150
# 7419              21300               14250
#
# [112 rows x 27 columns]

# %%
grouped.nth([1, -1])
# Out:
#                                                      INSTNM  \
# STABBR RELAFFIL
# AK     0                     University of Alaska Fairbanks
#        0                                  Ilisagvik College
#        1                          Alaska Pacific University
#        1                           Alaska Christian College
# AL     0                University of Alabama at Birmingham
# ...                                                     ...
# WV     0         BridgeValley Community & Technical College
#        1                          Appalachian Bible College
#        1         West Virginia Business College-Nutter Fort
# WY     0                            Central Wyoming College
#        0                            CollegeAmerica-Cheyenne
#
#                               CITY  ...  MD_EARN_WNE_P10  GRAD_DEBT_MDN_SUPP
# STABBR RELAFFIL                     ...
# AK     0                 Fairbanks  ...            36200               19355
#        0                    Barrow  ...            24900   PrivacySuppressed
#        1                 Anchorage  ...            47000               23250
#        1                  Soldotna  ...              NaN   PrivacySuppressed
# AL     0                Birmingham  ...            39700             21941.5
# ...                            ...  ...              ...                 ...
# WV     0         South  Charleston  ...              NaN              9429.5
#        1                Mount Hope  ...            28700                9300
#        1               Nutter Fort  ...            16700               19258
# WY     0                  Riverton  ...            25200                8757
#        0                  Cheyenne  ...            25600             27235.5
#
# [213 rows x 25 columns]

# %% [markdown]
# ## 9.7 過濾特定的組別

# %%
college = pd.read_csv('data/college.csv', index_col='INSTNM')
grouped = college.groupby('STABBR')
grouped.ngroups
# Out:
# 59

# %%
college['STABBR'].nunique()
# Out:
# 59

# %%
def check_minority(df, threshold):
    minority_pct = 1 - df['UGDS_WHITE']
    total_minority = (df['UGDS'] * minority_pct).sum()
    total_ugds = df['UGDS'].sum()
    total_minority_pct = total_minority / total_ugds
    return total_minority_pct > threshold

# %%
college_filtered = grouped.filter(check_minority, threshold=.5)
college_filtered
# Out:
#                                                            CITY STABBR  ...  \
# INSTNM                                                                  ...
# Everest College-Phoenix                                 Phoenix     AZ  ...
# Collins College                                         Phoenix     AZ  ...
# Empire Beauty School-Paradise Valley                    Phoenix     AZ  ...
# Empire Beauty School-Tucson                              Tucson     AZ  ...
# Thunderbird School of Global Management                Glendale     AZ  ...
# ...                                                         ...    ...  ...
# WestMed College - Merced                                 Merced     CA  ...
# Vantage College                                         El Paso     TX  ...
# SAE Institute of Technology  San Francisco           Emeryville     CA  ...
# Bay Area Medical Academy - San Jose Satellite L...     San Jose     CA  ...
# Excel Learning Center-San Antonio South             San Antonio     TX  ...
#
#                                                     MD_EARN_WNE_P10  \
# INSTNM
# Everest College-Phoenix                                       28600
# Collins College                                               25700
# Empire Beauty School-Paradise Valley                          17800
# Empire Beauty School-Tucson                                   18200
# Thunderbird School of Global Management                      118900
# ...                                                             ...
# WestMed College - Merced                                        NaN
# Vantage College                                                 NaN
# SAE Institute of Technology  San Francisco                      NaN
# Bay Area Medical Academy - San Jose Satellite L...              NaN
# Excel Learning Center-San Antonio South                         NaN
#
#                                                     GRAD_DEBT_MDN_SUPP
# INSTNM
# Everest College-Phoenix                                           9500
# Collins College                                                  47000
# Empire Beauty School-Paradise Valley                              9588
# Empire Beauty School-Tucson                                       9833
# Thunderbird School of Global Management              PrivacySuppressed
# ...                                                                ...
# WestMed College - Merced                                       15623.5
# Vantage College                                                   9500
# SAE Institute of Technology  San Francisco                        9500
# Bay Area Medical Academy - San Jose Satellite L...   PrivacySuppressed
# Excel Learning Center-San Antonio South                          12125
#
# [3028 rows x 26 columns]

# %%
college.shape
# Out:
# (7535, 26)

# %%
college_filtered.shape
# Out:
# (3028, 26)

# %%
college_filtered['STABBR'].nunique()
# Out:
# 20

# %%
college_filtered_20 = grouped.filter(check_minority, threshold=.2)
college_filtered_20.shape
# Out:
# (7461, 26)

# %%
college_filtered_20['STABBR'].nunique()
# Out:
# 57

# %%
college_filtered_70 = grouped.filter(check_minority, threshold=.7)
college_filtered_70.shape
# Out:
# (957, 26)

# %%
college_filtered_70['STABBR'].nunique()
# Out:
# 10

# %% [markdown]
# ## 9.8 分組轉換特定欄位的資料

# %%
weight_loss = pd.read_csv('data/weight_loss.csv')
weight_loss.query('Month == "Jan"')
# Out:
#   Name Month    Week  Weight
# 0  Bob   Jan  Week 1     291
# 1  Amy   Jan  Week 1     197
# 2  Bob   Jan  Week 2     288
# 3  Amy   Jan  Week 2     189
# 4  Bob   Jan  Week 3     283
# 5  Amy   Jan  Week 3     189
# 6  Bob   Jan  Week 4     283
# 7  Amy   Jan  Week 4     190

# %%
def percent_loss(s):
    return ((s - s.iloc[0]) / s.iloc[0]) * 100

# %%
(weight_loss
    .query('Name=="Bob" and Month=="Jan"')
    ['Weight']
    .pipe(percent_loss)
)
# Out:
# 0    0.000000
# 2   -1.030928
# 4   -2.749141
# 6   -2.749141
# Name: Weight, dtype: float64

# %%
(weight_loss
    .groupby(['Name', 'Month'])
    ['Weight'] 
    .transform(percent_loss)
)
# Out:
# 0     0.000000
# 1     0.000000
# 2    -1.030928
# 3    -4.060914
# 4    -2.749141
#         ...
# 27   -3.529412
# 28   -3.065134
# 29   -3.529412
# 30   -4.214559
# 31   -5.294118
# Name: Weight, Length: 32, dtype: float64

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Name=="Bob" and Month in ["Jan", "Feb"]')
)
# Out:
#    Name Month  ... Weight  percent_loss
# 0   Bob   Jan  ...    291           0.0
# 2   Bob   Jan  ...    288          -1.0
# 4   Bob   Jan  ...    283          -2.7
# 6   Bob   Jan  ...    283          -2.7
# 8   Bob   Feb  ...    283           0.0
# 10  Bob   Feb  ...    275          -2.8
# 12  Bob   Feb  ...    268          -5.3
# 14  Bob   Feb  ...    268          -5.3
#
# [8 rows x 5 columns]

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
)
# Out:
#    Name Month  ... Weight  percent_loss
# 6   Bob   Jan  ...    283          -2.7
# 7   Amy   Jan  ...    190          -3.6
# 14  Bob   Feb  ...    268          -5.3
# 15  Amy   Feb  ...    173          -8.9
# 22  Bob   Mar  ...    261          -2.6
# 23  Amy   Mar  ...    170          -1.7
# 30  Bob   Apr  ...    250          -4.2
# 31  Amy   Apr  ...    161          -5.3
#
# [8 rows x 5 columns]

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
)
# Out:
# Name   Amy  Bob
# Month
# Apr   -5.3 -4.2
# Feb   -8.9 -5.3
# Jan   -3.6 -2.7
# Mar   -1.7 -2.6

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
)
# Out:
# Name   Amy  Bob winner
# Month
# Apr   -5.3 -4.2    Amy
# Feb   -8.9 -5.3    Amy
# Jan   -3.6 -2.7    Amy
# Mar   -1.7 -2.6    Bob

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
    .style.highlight_min(axis=1,color='lightgrey')
)
# Out:
# <style  type="text/css" >
#     #T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col0 {
#             background-color:  lightgrey;
#         }    #T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col0 {
#             background-color:  lightgrey;
#         }    #T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col0 {
#             background-color:  lightgrey;
#         }    #T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col1 {
#             background-color:  lightgrey;
#         }</style><table id="T_ce7eb106_428d_11ec_9423_74c63be20db0" ><thead>    <tr>        <th class="index_name level0" >Name</th>        <th class="col_heading level0 col0" >Amy</th>        <th class="col_heading level0 col1" >Bob</th>        <th class="col_heading level0 col2" >winner</th>    </tr>    <tr>        <th class="index_name level0" >Month</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row0" class="row_heading level0 row0" >Apr</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col0" class="data row0 col0" >-5.300000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col1" class="data row0 col1" >-4.200000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row0_col2" class="data row0 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row1" class="row_heading level0 row1" >Feb</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col0" class="data row1 col0" >-8.900000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col1" class="data row1 col1" >-5.300000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row1_col2" class="data row1 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row2" class="row_heading level0 row2" >Jan</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col0" class="data row2 col0" >-3.600000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col1" class="data row2 col1" >-2.700000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row2_col2" class="data row2 col2" >Amy</td>
#             </tr>
#             <tr>
#                         <th id="T_ce7eb106_428d_11ec_9423_74c63be20db0level0_row3" class="row_heading level0 row3" >Mar</th>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col0" class="data row3 col0" >-1.700000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col1" class="data row3 col1" >-2.600000</td>
#                         <td id="T_ce7eb106_428d_11ec_9423_74c63be20db0row3_col2" class="data row3 col2" >Bob</td>
#             </tr>
#     </tbody></table>

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
    .assign(winner=lambda df_:
            np.where(df_.Amy < df_.Bob, 'Amy', 'Bob'))
    .winner
    .value_counts()
)
# Out:
# Amy    3
# Bob    1
# Name: winner, dtype: int64

# %%
(weight_loss
    .assign(percent_loss=(weight_loss
        .groupby(['Name', 'Month'])
        ['Weight'] 
        .transform(percent_loss)
        .round(1)),
            Month=pd.Categorical(weight_loss.Month,
                  categories=['Jan', 'Feb', 'Mar', 'Apr'],
                  ordered=True))
    .query('Week == "Week 4"')
    .pivot(index='Month', columns='Name',
           values='percent_loss')
)
# Out:
# Name   Amy  Bob
# Month
# Jan   -3.6 -2.7
# Feb   -8.9 -5.3
# Mar   -1.7 -2.6
# Apr   -5.3 -4.2

# %% [markdown]
# ## 9.9 使用apply()計算加權平均數

# %%
college = pd.read_csv('data/college.csv')
subset = ['UGDS', 'SATMTMID', 'SATVRMID']
college2 = college.dropna(subset=subset)
college.shape
# Out:
# (7535, 27)

# %%
college2.shape
# Out:
# (1184, 27)

# %%
def weighted_math_average(df):
    weighted_math = df['UGDS'] * df['SATMTMID']
    return int(weighted_math.sum() / df['UGDS'].sum())

# %%
college2.groupby('STABBR').apply(weighted_math_average)
# Out:
# STABBR
# AK    503
# AL    536
# AR    529
# AZ    569
# CA    564
#      ...
# VT    566
# WA    555
# WI    593
# WV    500
# WY    540
# Length: 53, dtype: int64

# %%
# (college2
#     .groupby('STABBR')
#     .agg(weighted_math_average)
# )

# %%
# (college2
#     .groupby('STABBR')
#     ['SATMTMID'] 
#     .agg(weighted_math_average)
# )

# %%
def weighted_average(df):
    weight_m = df['UGDS'] * df['SATMTMID']
    weight_v = df['UGDS'] * df['SATVRMID']
    wm_avg = weight_m.sum() / df['UGDS'].sum()
    wv_avg = weight_v.sum() / df['UGDS'].sum()
    data = {'w_math_avg': wm_avg,
            'w_verbal_avg': wv_avg,
            'math_avg': df['SATMTMID'].mean(),
            'verbal_avg': df['SATVRMID'].mean(),
            'count': len(df)
    }
    return pd.Series(data)

# %%
weighted_average(college2)
# Out:
# w_math_avg       559.408812
# w_verbal_avg     542.989462
# math_avg         530.958615
# verbal_avg       522.775338
# count           1184.000000
# dtype: float64

# %%
(college2
    .groupby('STABBR')
    .apply(weighted_average)
    .astype(int)
)
# Out:
#         w_math_avg  w_verbal_avg  ...  verbal_avg  count
# STABBR                            ...
# AK             503           555  ...         555      1
# AL             536           533  ...         508     21
# AR             529           504  ...         491     16
# AZ             569           557  ...         538      6
# CA             564           539  ...         549     72
# ...            ...           ...  ...         ...    ...
# VT             566           564  ...         527      8
# WA             555           541  ...         548     18
# WI             593           556  ...         516     14
# WV             500           487  ...         473     17
# WY             540           535  ...         535      1
#
# [53 rows x 5 columns]

# %%
from scipy.stats import gmean, hmean
def calculate_means(df):
    df_means = pd.DataFrame(index=['Arithmetic', 'Weighted',
                                   'Geometric', 'Harmonic'])
    cols = ['SATMTMID', 'SATVRMID']
    for col in cols:
        arithmetic = df[col].mean()
        weighted = np.average(df[col], weights=df['UGDS'])
        geometric = gmean(df[col])
        harmonic = hmean(df[col])
        df_means[col] = [arithmetic, weighted,
                         geometric, harmonic]
    df_means['count'] = len(df)
    return df_means.astype(int)
(college2
    .groupby('STABBR')
    .apply(calculate_means)
)
# Out:
#                    SATMTMID  SATVRMID  count
# STABBR
# AK     Arithmetic       503       555      1
#        Weighted         503       555      1
#        Geometric        503       555      1
#        Harmonic         503       555      1
# AL     Arithmetic       504       508     21
# ...                     ...       ...    ...
# WV     Harmonic         480       472     17
# WY     Arithmetic       540       535      1
#        Weighted         540       535      1
#        Geometric        540       534      1
#        Harmonic         540       535      1
#
# [212 rows x 3 columns]

# %% [markdown]
# ## 9.10 以連續變化的數值進行分組

# %%
flights = pd.read_csv('data/flights.csv')
flights
# Out:
#        MONTH  DAY  ...  DIVERTED CANCELLED
# 0          1    1  ...         0         0
# 1          1    1  ...         0         0
# 2          1    1  ...         0         0
# 3          1    1  ...         0         0
# 4          1    1  ...         0         0
# ...      ...  ...  ...       ...       ...
# 58487     12   31  ...         0         0
# 58488     12   31  ...         0         0
# 58489     12   31  ...         0         0
# 58490     12   31  ...         0         0
# 58491     12   31  ...         0         0
#
# [58492 rows x 14 columns]

# %%
bins = [-np.inf, 200, 500, 1000, 2000, np.inf]
cuts = pd.cut(flights['DIST'], bins=bins)
cuts
# Out:
# 0         (500.0, 1000.0]
# 1        (1000.0, 2000.0]
# 2         (500.0, 1000.0]
# 3        (1000.0, 2000.0]
# 4        (1000.0, 2000.0]
#                ...
# 58487    (1000.0, 2000.0]
# 58488      (200.0, 500.0]
# 58489      (200.0, 500.0]
# 58490     (500.0, 1000.0]
# 58491     (500.0, 1000.0]
# Name: DIST, Length: 58492, dtype: category
# Categories (5, interval[float64]): [(-inf, 200.0] < (200.0, 500.0] < (500.0, 1000.0] < (1000.0, 2000.0] < (2000.0, inf]]

# %%
cuts.value_counts()
# Out:
# (500.0, 1000.0]     20659
# (200.0, 500.0]      15874
# (1000.0, 2000.0]    14186
# (2000.0, inf]        4054
# (-inf, 200.0]        3719
# Name: DIST, dtype: int64

# %%
(flights
    .groupby(cuts)
    ['AIRLINE']
    .value_counts(normalize=True) 
    .round(3)
)
# Out:
# DIST           AIRLINE
# (-inf, 200.0]  OO         0.326
#                EV         0.289
#                MQ         0.211
#                DL         0.086
#                AA         0.052
#                           ...
# (2000.0, inf]  WN         0.046
#                HA         0.028
#                NK         0.019
#                AS         0.012
#                F9         0.004
# Name: AIRLINE, Length: 57, dtype: float64

# %%
(flights
  .groupby(cuts)
  ['AIR_TIME']
  .quantile(q=[.25, .5, .75]) 
  .div(60)
  .round(2)
)
# Out:
# DIST
# (-inf, 200.0]     0.25    0.43
#                   0.50    0.50
#                   0.75    0.57
# (200.0, 500.0]    0.25    0.77
#                   0.50    0.92
#                           ...
# (1000.0, 2000.0]  0.50    2.93
#                   0.75    3.40
# (2000.0, inf]     0.25    4.30
#                   0.50    4.70
#                   0.75    5.03
# Name: AIR_TIME, Length: 15, dtype: float64

# %% [markdown]
# ## 9.11 案例演練：計算城市之間的航班總數

# %%
flights = pd.read_csv('data/flights.csv')
flights_ct = flights.groupby(['ORG_AIR', 'DEST_AIR']).size()
flights_ct
# Out:
# ORG_AIR  DEST_AIR
# ATL      ABE          31
#          ABQ          16
#          ABY          19
#          ACY           6
#          AEX          40
#                     ...
# SFO      SNA         122
#          STL          20
#          SUN          10
#          TUS          20
#          XNA           2
# Length: 1130, dtype: int64

# %%
flights_ct.loc[[('ATL', 'IAH'), ('IAH', 'ATL')]]
# Out:
# ORG_AIR  DEST_AIR
# ATL      IAH         121
# IAH      ATL         148
# dtype: int64

# %%
f_part3 = (flights  
  [['ORG_AIR', 'DEST_AIR']] 
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
)
f_part3
# Out:
#          0    1
# 0      LAX  SLC
# 1      DEN  IAD
# 2      DFW  VPS
# 3      DCA  DFW
# 4      LAX  MCI
# ...    ...  ...
# 58487  DFW  SFO
# 58488  LAS  SFO
# 58489  SBA  SFO
# 58490  ATL  MSP
# 58491  BOI  SFO
#
# [58492 rows x 2 columns]

# %%
rename_dict = {0:'AIR1', 1:'AIR2'}  
(flights    
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
)
# Out:
# AIR1  AIR2
# ABE   ATL      31
#       ORD      24
# ABI   DFW      74
# ABQ   ATL      16
#       DEN      46
#              ...
# SFO   SNA     122
#       STL      20
#       SUN      10
#       TUS      20
#       XNA       2
# Length: 1085, dtype: int64

# %%
(flights     
  [['ORG_AIR', 'DEST_AIR']]
  .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
  .rename(columns=rename_dict)
  .groupby(['AIR1', 'AIR2'])
  .size()
  .loc[('ATL', 'IAH')]
)
# Out:
# 269

# %%
# (flights     
#   [['ORG_AIR', 'DEST_AIR']]
#   .apply(lambda ser:
#          ser.sort_values().reset_index(drop=True),
#          axis='columns')
#   .rename(columns=rename_dict)
#   .groupby(['AIR1', 'AIR2'])
#   .size()
#   .loc[('IAH', 'ATL')]
# )

# %%
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
data_sorted[:10]
# Out:
# array([['LAX', 'SLC'],
#        ['DEN', 'IAD'],
#        ['DFW', 'VPS'],
#        ['DCA', 'DFW'],
#        ['LAX', 'MCI'],
#        ['IAH', 'SAN'],
#        ['DFW', 'MSY'],
#        ['PHX', 'SFO'],
#        ['ORD', 'STL'],
#        ['IAH', 'SJC']], dtype=object)

# %%
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
flights_sort2.equals(f_part3.rename(columns={0:'AIR1', 1:'AIR2'}))
# Out:
# True

# %%
# %%timeit
flights_sort = (flights   # doctest: +SKIP
    [['ORG_AIR', 'DEST_AIR']] 
   .apply(lambda ser:
         ser.sort_values().reset_index(drop=True),
         axis='columns')
)
# Out:
# 50.8 s ± 4.86 s per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
data_sorted = np.sort(flights[['ORG_AIR', 'DEST_AIR']])
flights_sort2 = pd.DataFrame(data_sorted, columns=['AIR1', 'AIR2'])
# Out:
# 13.2 ms ± 911 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ## 9.12 案例演練：尋找航班的連續準時記錄

# %%
s = pd.Series([0, 1, 1, 0, 1, 1, 1, 0])
s
# Out:
# 0    0
# 1    1
# 2    1
# 3    0
# 4    1
# 5    1
# 6    1
# 7    0
# dtype: int64

# %%
s1 = s.cumsum()
s1
# Out:
# 0    0
# 1    1
# 2    2
# 3    2
# 4    3
# 5    4
# 6    5
# 7    5
# dtype: int64

# %%
s.mul(s1)
# Out:
# 0    0
# 1    1
# 2    2
# 3    0
# 4    3
# 5    4
# 6    5
# 7    0
# dtype: int64

# %%
s.mul(s1).diff()
# Out:
# 0    NaN
# 1    1.0
# 2    1.0
# 3   -2.0
# 4    3.0
# 5    1.0
# 6    1.0
# 7   -5.0
# dtype: float64

# %%
(s.mul(s.cumsum())
  .diff()
  .where(lambda x: x < 0))
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -2.0
# 4    NaN
# 5    NaN
# 6    NaN
# 7   -5.0
# dtype: float64

# %%
(s.mul(s.cumsum())
  .diff()
  .where(lambda x: x < 0)
  .ffill())
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3   -2.0
# 4   -2.0
# 5   -2.0
# 6   -2.0
# 7   -5.0
# dtype: float64

# %%
(s.mul(s.cumsum())
  .diff()
  .where(lambda x: x < 0)
  .ffill()
  .add(s.cumsum(), fill_value=0))
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# 3    0.0
# 4    1.0
# 5    2.0
# 6    3.0
# 7    0.0
# dtype: float64

# %%
flights = pd.read_csv('data/flights.csv')
(flights.assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
        [['AIRLINE', 'ORG_AIR', 'ON_TIME']])
# Out:
#       AIRLINE ORG_AIR  ON_TIME
# 0          WN     LAX        0
# 1          UA     DEN        1
# 2          MQ     DFW        0
# 3          AA     DFW        1
# 4          WN     LAX        0
# ...       ...     ...      ...
# 58487      AA     SFO        1
# 58488      F9     LAS        1
# 58489      OO     SFO        1
# 58490      WN     MSP        0
# 58491      OO     SFO        1
#
# [58492 rows x 3 columns]

# %%
def max_streak(s):
    s1 = s.cumsum()
    return (s.mul(s1)
             .diff()
             .where(lambda x: x < 0) 
             .ffill()
             .add(s1, fill_value=0)
             .max())

# %%
(flights
    .assign(ON_TIME=flights['ARR_DELAY'].lt(15).astype(int))
    .sort_values(['MONTH', 'DAY', 'SCHED_DEP']) 
    .groupby(['AIRLINE', 'ORG_AIR'])
    ['ON_TIME'] 
    .agg(['mean', 'size', max_streak])
    .round(2)
)
# Out:
#                  mean  size  max_streak
# AIRLINE ORG_AIR
# AA      ATL      0.82   233          15
#         DEN      0.74   219          17
#         DFW      0.78  4006          64
#         IAH      0.80   196          24
#         LAS      0.79   374          29
# ...               ...   ...         ...
# WN      LAS      0.77  2031          39
#         LAX      0.70  1135          23
#         MSP      0.84   237          32
#         PHX      0.77  1724          33
#         SFO      0.76   445          17
#
# [114 rows x 3 columns]
